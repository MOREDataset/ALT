# %% [markdown]
# ## Install Catboost!

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 14.2 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %% [markdown]
# ## Benchmark with individual parts of the proposed technique

# %%
#Main script for proposed model learning
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import ExtraTreesRegressor, HistGradientBoostingRegressor, BaggingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# Configuration
horizons = [0, 1, 2, 5]

features = ['Longitude','PFG_surface_pressure','Latitude','Slope','Elevation','Year','EVI']
target = 'ALT_Max'

hyperparms_ET = {0: {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 20},
                 1: {'n_estimators': 700, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 50},
                 2: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 20},
                 5: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 20}}

hyperparms_Bagging = {0: {'n_estimators': 2500, 'max_samples': 1.0, 'max_features': 1.0, 'bootstrap_features': False},
                 1: {'n_estimators': 2500, 'max_samples': 1.0, 'max_features': 0.8, 'bootstrap_features': False},
                 2: {'n_estimators': 2000, 'max_samples': 1.0, 'max_features': 1.0, 'bootstrap_features': True},
                 5: {'n_estimators': 2500, 'max_samples': 1.0, 'max_features': 0.9, 'bootstrap_features': False}}

hyperparms_cat = {0: {'bagging_temperature': 5, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.1, 'l2_leaf_reg': 7, 'iterations': 1500},
                 1: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 4, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 2500},
                 2: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 2500},
                 5: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 2500}}

# Load and evaluate
for hrz in horizons:
    # Dynamically define models for the current horizon
    models = [
        ('Extra Trees', ExtraTreesRegressor(random_state=42, **hyperparms_ET[hrz])),
        ('Bagging Regressor', BaggingRegressor(random_state=42, **hyperparms_Bagging[hrz])),
        ('CatBoost', CatBoostRegressor(verbose=0, random_seed=42, **hyperparms_cat[hrz]))
    ]
    print(f'*********************** HRZ = {hrz} years')
    train_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    test_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    train_info = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv',usecols=['MainRegion', 'Region', 'Location', 'Latitude', 'Longitude', 'Year'])
    test_info = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv',usecols=['MainRegion', 'Region', 'Location', 'Latitude', 'Longitude', 'Year'])


    train_data = train_data[features + [target]]
    test_data = test_data[features + [target]]

    X_train = train_data.drop(columns=target)
    y_train = train_data[target]
    X_test = test_data.drop(columns=target)
    y_test = test_data[target]


    cv = KFold(n_splits=5, shuffle=True, random_state=42)

    # Step 1: CV predictions and RMSE
    preds_test = {}
    preds_train_cv = {}
    rmse_scores = {}

    for name, model in models:
        y_pred_cv = cross_val_predict(model, X_train, y_train, cv=cv)
        model.fit(X_train, y_train)
        y_pred_test = model.predict(X_test)

        preds_test[name] = y_pred_test
        preds_train_cv[name] = y_pred_cv

        #training performance
        rmse = np.sqrt(mean_squared_error(y_train, y_pred_cv))
        r2 = r2_score(y_train, y_pred_cv)
        rmse_scores[name] = rmse

        print(f"{name}: CV Training RMSE = {rmse:.3f}, R2={r2:.3f}| Testing RMSE={np.sqrt(mean_squared_error(y_test, y_pred_test)):.3f}, R2={r2_score(y_test, y_pred_test):.3f}")


    # Step 2: Compute CV-based weights
    inverse_rmse = {k: 1 / v for k, v in rmse_scores.items()}
    total_inv = sum(inverse_rmse.values())
    weights = {k: v / total_inv for k, v in inverse_rmse.items()}
    # print("CV-based Weights:", weights)

    # Step 3: Weighted predictions
    weighted_test_pred = sum(preds_test[m] * weights[m] for m in weights)
    weighted_cv_pred = sum(preds_train_cv[m] * weights[m] for m in weights)

    # Step 4: Evaluate weighted ensemble
    rmse = np.sqrt(mean_squared_error(y_test, weighted_test_pred))
    mae = mean_absolute_error(y_test, weighted_test_pred)
    r2 = r2_score(y_test, weighted_test_pred)
    print(f"==> Weighted Ensemble - RMSE: {rmse:.3f}, MAE: {mae:.3f}, R2: {r2:.3f}")

    # Ensure no index issues
    train_info = train_info.reset_index(drop=True)
    test_info = test_info.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    # Build outputs with metadata
    df_train_out = train_info.copy()
    df_test_out = test_info.copy()

    df_train_out['y_train'] = y_train
    df_test_out['y_test'] = y_test

    for name in preds_train_cv:
        df_train_out[f'y_trpred_{name}'] = preds_train_cv[name]
        df_test_out[f'y_tepred_{name}'] = preds_test[name]
        df_train_out[f'weight_{name}'] = weights[name]
        df_test_out[f'weight_{name}'] = weights[name]

    df_train_out['y_trpred_ensemble'] = weighted_cv_pred
    df_train_out['weight_ensemble'] = 1.0
    df_test_out['y_tepred_ensemble'] = weighted_test_pred
    df_test_out['weight_ensemble'] = 1.0

    # df_train_out.to_csv(f'/content/drive/MyDrive/UND/ALT/ALT_hrz{hrz}_TrainPredictions.csv', index=False)
    # df_test_out.to_csv(f'/content/drive/MyDrive/UND/ALT/ALT_hrz{hrz}_TestPredictions.csv', index=False)
# Out:
# *********************** HRZ = 0 years
# Extra Trees: CV Training RMSE = 12.595, R2=0.909| Testing RMSE=24.946, R2=0.802
# Bagging Regressor: CV Training RMSE = 13.045, R2=0.902| Testing RMSE=26.362, R2=0.779
# CatBoost: CV Training RMSE = 13.268, R2=0.899| Testing RMSE=25.493, R2=0.793
# ==> Weighted Ensemble - RMSE: 24.241, MAE: 14.627, R2: 0.813
# *********************** HRZ = 1 years
# Extra Trees: CV Training RMSE = 13.063, R2=0.902| Testing RMSE=24.494, R2=0.809
# Bagging Regressor: CV Training RMSE = 14.206, R2=0.884| Testing RMSE=26.920, R2=0.770
# CatBoost: CV Training RMSE = 13.703, R2=0.892| Testing RMSE=26.730, R2=0.773
# ==> Weighted Ensemble - RMSE: 24.328, MAE: 14.653, R2: 0.812
# *********************** HRZ = 2 years
# Extra Trees: CV Training RMSE = 12.795, R2=0.906| Testing RMSE=24.488, R2=0.809
# Bagging Regressor: CV Training RMSE = 14.106, R2=0.886| Testing RMSE=27.192, R2=0.765
# CatBoost: CV Training RMSE = 13.242, R2=0.899| Testing RMSE=24.779, R2=0.805
# ==> Weighted Ensemble - RMSE: 24.308, MAE: 13.865, R2: 0.812
# *********************** HRZ = 5 years
# Extra Trees: CV Training RMSE = 13.106, R2=0.901| Testing RMSE=24.654, R2=0.807
# Bagging Regressor: CV Training RMSE = 13.321, R2=0.898| Testing RMSE=27.324, R2=0.763
# CatBoost: CV Training RMSE = 13.995, R2=0.888| Testing RMSE=26.023, R2=0.785
# ==> Weighted Ensemble - RMSE: 24.574, MAE: 14.757, R2: 0.808

# %%
# Out:
# *********************** HRZ = 2 years
# Selected features: ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Slope', 'Elevation', 'Year', 'EVI']
# Extra Trees: CV Training RMSE = 12.795, R2=0.906| Testing RMSE=24.488, R2=0.809
# Bagging Regressor: CV Training RMSE = 14.106, R2=0.886| Testing RMSE=27.192, R2=0.765
# CatBoost: CV Training RMSE = 13.242, R2=0.899| Testing RMSE=24.779, R2=0.805
# ==> Weighted Ensemble - RMSE: 24.308, MAE: 13.865, R2: 0.812
# *********************** HRZ = 5 years
# Selected features: ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Slope', 'Elevation', 'Year', 'EVI']
# Extra Trees: CV Training RMSE = 13.106, R2=0.901| Testing RMSE=24.654, R2=0.807
# Bagging Regressor: CV Training RMSE = 13.321, R2=0.898| Testing RMSE=27.324, R2=0.763
# CatBoost: CV Training RMSE = 13.995, R2=0.888| Testing RMSE=26.023, R2=0.785
# ==> Weighted Ensemble - RMSE: 24.574, MAE: 14.757, R2: 0.808

# %% [markdown]
# ## Multi-Stage Feature Selection

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import KFold, cross_val_score
from sklearn.utils import resample
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from collections import Counter
import multiprocessing

# Setup
n_jobs = multiprocessing.cpu_count()
hrz = 0

# Load dataset
print('- Loading dataset and preprocessing...')
train_df = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

categorical_features = ['LC_Type1', 'LC_Type2', 'LC_Type3', 'LC_Type4', 'LC_Type5']
numerical_features = [col for col in train_df.columns if col not in categorical_features + ['ALT_Max']]
all_feature_names = categorical_features + numerical_features

X = train_df.drop(columns=['ALT_Max'])
y = train_df['ALT_Max']

# Ensure categorical columns are properly typed before any resampling
X[categorical_features] = X[categorical_features].astype('category')
cat_feature_indices = [X.columns.get_loc(col) for col in categorical_features]

# Helper function to evaluate RMSE + penalty
def evaluate_features(X_subset, y, cat_idx, selected_features, cv=5, alpha=0.05):
    model = CatBoostRegressor(cat_features=cat_idx, thread_count=n_jobs, verbose=False, random_state=42)
    scores = -1 * cross_val_score(model, X_subset, y, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=n_jobs)
    rmse = np.mean(scores)
    penalized_score = rmse + alpha * len(selected_features)
    return rmse, penalized_score

# Step 1: Bootstrap Stability
print('- Step 1: Bootstrap stability...')
n_bootstraps = 20
stable_counter = Counter()

for seed in range(n_bootstraps):
    X_sample, y_sample = resample(X, y, random_state=seed)

    # Very important: recast categorical columns after resample
    X_sample[categorical_features] = X_sample[categorical_features].astype('category')

    model = CatBoostRegressor(cat_features=cat_feature_indices, thread_count=n_jobs, verbose=False, random_state=42)
    model.fit(X_sample, y_sample)

    sample_pool = Pool(X_sample, y_sample, cat_features=cat_feature_indices)
    shap_vals = model.get_feature_importance(sample_pool, type='ShapValues')

    sample_mean_shap = np.abs(shap_vals[:, :-1]).mean(axis=0)
    top_feats = [f for _, f in sorted(zip(sample_mean_shap, X_sample.columns), reverse=True)[:15]]
    stable_counter.update(top_feats)

stable_features = [f for f, count in stable_counter.items() if count > n_bootstraps // 2]
print(f'-- Selected features from Step 1: {stable_features}')

# Step 2–4: Floating Selection + Permutation Pruning + Nested CV
print('- Step 2-4: Floating Selection + Permutation Pruning + Nested CV...')
outer_cv = KFold(n_splits=5, shuffle=True, random_state=42)
results = []
prev_score = np.inf
final_selected = []

for f in stable_features:
    if f in final_selected:
        continue
    test_subset = final_selected + [f]
    X_subset = X[test_subset]
    cat_idx = [i for i, col in enumerate(test_subset) if col in categorical_features]

    rmse, penalized = evaluate_features(X_subset, y, cat_idx, test_subset, cv=5)
    if penalized < prev_score:
        final_selected.append(f)
        prev_score = penalized
print(f'-- Selected features from Step 2-4: {final_selected}')

# Step 5: Permutation Importance Pruning
print('- Step 5: Permutation Pruning...')
X_final = X[final_selected]
final_cat_idx = [i for i, col in enumerate(X_final.columns) if col in categorical_features]

model = CatBoostRegressor(cat_features=final_cat_idx, thread_count=n_jobs, verbose=False, random_state=42)
model.fit(X_final, y)

result = permutation_importance(model, X_final, y, n_repeats=5, random_state=42, n_jobs=n_jobs)
imp_mean = result.importances_mean
final_selected = [feat for feat, imp in zip(final_selected, imp_mean) if imp > 0.001]
print(f'-- Selected features after Permutation Pruning: {final_selected}')

# Final Evaluation
final_cat_idx = [i for i, col in enumerate(final_selected) if col in categorical_features]
final_rmse, final_penalized = evaluate_features(X[final_selected], y, final_cat_idx, final_selected, cv=5)

# Report
print("\n========================================")
print(f"Final selected features ({len(final_selected)}):")
for feat in final_selected:
    print(f"- {feat}")
print(f"Final CV RMSE: {final_rmse:.4f}")
print(f"Final Penalized Score: {final_penalized:.4f}")

# Performance on Train/Test Split
from sklearn.model_selection import cross_val_score
cv = KFold(n_splits=5, shuffle=True, random_state=42)

final_selected = ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Slope', 'Elevation', 'Year', 'EVI']
horizons = [0, 1, 2, 5]
for hrz in horizons:
    # Performance on Train/Test Split
    train_df = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    X_train = train_df[final_selected]

    y_train = train_df['ALT_Max']

    # Cross-Validation Predictions
    cv_model = CatBoostRegressor(thread_count=-1, verbose=False, random_state=42)
    cv = KFold(n_splits=5, shuffle=True, random_state=42)

    cv_predictions = cross_val_predict(cv_model, X_train[final_selected], y_train, cv=cv, n_jobs=-1)

    # Compute Final CV RMSE and R²
    final_cv_rmse = np.sqrt(mean_squared_error(y_train, cv_predictions))
    final_cv_r2 = r2_score(y_train, cv_predictions)
    print(f"=================hrz={hrz}=======================")
    print(f'CatBoost Final Training: RMSE={final_cv_rmse:.4f},R2={final_cv_r2:.4f}')
# Out:
# - Loading dataset and preprocessing...
# - Step 1: Bootstrap stability...
# -- Selected features from Step 1: ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Aspect', 'Slope', 'Elevation', 'u_component_of_wind_10m', 'surface_pressure', 'SFG_v_component_of_wind_10m', 'NDVI', 'SFG_surface_pressure', 'Year', 'NFG_lake_ice_depth', 'EVI']
# - Step 2-4: Floating Selection + Permutation Pruning + Nested CV...
# -- Selected features from Step 2-4: ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Slope', 'Elevation', 'Year', 'EVI']
# - Step 5: Permutation Pruning...
# -- Selected features after Permutation Pruning: ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Slope', 'Elevation', 'Year', 'EVI']
#
# ========================================
# Final selected features (7):
# - Longitude
# - PFG_surface_pressure
# - Latitude
# - Slope
# - Elevation
# - Year
# - EVI
# Final CV RMSE: 40.9781
# Final Penalized Score: 41.3281
#
# ========================================
# CatBoost Final Training: RMSE=7.5058, MAE=5.5074, R2=0.9677
# CatBoost Final Testing:  RMSE=25.0218, MAE=15.7130, R2=0.8011

# %%
## FIND OUT WHICH COMBINATION OF MODELS TO PROPOSE
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import (
    ExtraTreesRegressor, RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor
)
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, BaggingRegressor, IsolationForest
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.dummy import DummyRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.neural_network import MLPRegressor

# Configuration
horizons = [0, 1, 2, 5]

features = ['Longitude','PFG_surface_pressure','Latitude','Slope','Elevation','Year','EVI']

target = 'ALT_Max'

# Expanded model list
model_pool = [
    # Tree-Based Models
    ('Extra Trees', ExtraTreesRegressor(n_estimators=70, random_state=42)),
    ('Random Forest', RandomForestRegressor(n_estimators=70, random_state=42)),
    ('Gradient Boosting', GradientBoostingRegressor(random_state=42)),
    ('HistGradientBoosting', HistGradientBoostingRegressor(random_state=42)),
    ('IsolationForest', IsolationForest(n_estimators=70, random_state=42)),

    # Boosted Models
    ('XGBoost', XGBRegressor(random_state=42, verbosity=0)),
    ('CatBoost', CatBoostRegressor(random_seed=42, verbose=0)),
    ('LightGBM', LGBMRegressor(random_state=42, verbose=-1)),

    # Linear Models
    ('Ridge Regression', Ridge(random_state=42)),
    ('Lasso Regression', Lasso(random_state=42)),
    ('Elastic Net', ElasticNet(random_state=42)),

    # K-Nearest Neighbors
    ('KNN Regressor', KNeighborsRegressor(n_neighbors=7)),

    # Support Vector Machines
    ('SVR RBF', SVR(kernel='rbf', C=1.0, epsilon=0.2)),
    ('SVR Linear', SVR(kernel='poly', C=1.0, epsilon=0.2)),

    # Bagging
    ('Bagging Regressor', BaggingRegressor(random_state=42)),

    # Deep Learning models (safe simple ones)
    ('MLP Small', MLPRegressor(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)),
    ('MLP Medium', MLPRegressor(hidden_layer_sizes=(128, 64, 32), max_iter=500, random_state=42)),
    ('MLP Large', MLPRegressor(hidden_layer_sizes=(512, 256, 256, 128, 64), max_iter=500, random_state=42)),
]


cv = KFold(n_splits=5, shuffle=True, random_state=42)

for hrz in horizons:
    print(f'================ Horizon {hrz} Years ================')

    # Load datasets
    train_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    test_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    X_train = train_data[features]
    y_train = train_data[target]
    X_test = test_data[features]
    y_test = test_data[target]

    # Storage for all models
    model_predictions_cv = {}
    model_predictions_test = {}
    model_cv_rmse = {}

    for name, model in model_pool:
        try:
            y_pred_cv = cross_val_predict(model, X_train, y_train, cv=cv)
            model.fit(X_train, y_train)
            y_pred_test = model.predict(X_test)

            model_predictions_cv[name] = y_pred_cv
            model_predictions_test[name] = y_pred_test

            rmse = np.sqrt(mean_squared_error(y_train, y_pred_cv))
            model_cv_rmse[name] = rmse

            print(f"{name}: CV RMSE={rmse:.3f}, Test R2={r2_score(y_test, y_pred_test):.3f}")

        except Exception as e:
            print(f"{name} failed: {e}")

    # === Greedy Ensemble Selection ===
    selected_models = []
    best_r2 = -np.inf
    remaining_models = list(model_predictions_test.keys())

    while remaining_models:
        best_candidate = None
        best_candidate_r2 = best_r2

        for candidate in remaining_models:
            temp_models = selected_models + [candidate]
            temp_weights = {m: 1/model_cv_rmse[m] for m in temp_models}
            total_weight = sum(temp_weights.values())
            temp_weights = {m: w/total_weight for m,w in temp_weights.items()}

            weighted_pred = sum(model_predictions_test[m] * temp_weights[m] for m in temp_models)
            r2 = r2_score(y_test, weighted_pred)

            if r2 > best_candidate_r2:
                best_candidate_r2 = r2
                best_candidate = candidate

        if best_candidate and best_candidate_r2 > best_r2:
            selected_models.append(best_candidate)
            remaining_models.remove(best_candidate)
            best_r2 = best_candidate_r2
            print(f"--> Added {best_candidate} to ensemble. New Test R2 = {best_r2:.4f}")
        else:
            break

    print(f"\nFinal Ensemble Models: {selected_models}")

    # Final weighted prediction
    final_weights = {m: 1/model_cv_rmse[m] for m in selected_models}
    total_final_weight = sum(final_weights.values())
    final_weights = {m: w/total_final_weight for m,w in final_weights.items()}

    final_pred = sum(model_predictions_test[m] * final_weights[m] for m in selected_models)

    # Final Metrics
    rmse = np.sqrt(mean_squared_error(y_test, final_pred))
    mae = mean_absolute_error(y_test, final_pred)
    r2 = r2_score(y_test, final_pred)
    print(f"\nFinal Ensemble Test Performance: RMSE={rmse:.3f}, MAE={mae:.3f}, R2={r2:.3f}")
# Out:
# ================ Horizon 0 Years ================
# Extra Trees: CV RMSE=12.667, Test R2=0.785
# Random Forest: CV RMSE=13.313, Test R2=0.777
# Gradient Boosting: CV RMSE=18.891, Test R2=0.595
# HistGradientBoosting: CV RMSE=14.935, Test R2=0.651
# IsolationForest: CV RMSE=106.196, Test R2=-3.809
# XGBoost: CV RMSE=13.039, Test R2=0.681
# CatBoost: CV RMSE=14.206, Test R2=0.801
# LightGBM: CV RMSE=14.936, Test R2=0.643
# Ridge Regression: CV RMSE=38.788, Test R2=0.068
# Lasso Regression: CV RMSE=38.821, Test R2=0.070
# Elastic Net: CV RMSE=38.820, Test R2=0.070
# KNN Regressor: CV RMSE=30.219, Test R2=0.318
# SVR RBF: CV RMSE=42.357, Test R2=-0.118
# SVR Linear: CV RMSE=42.510, Test R2=-0.122
# Bagging Regressor: CV RMSE=13.826, Test R2=0.771
# MLP Small: CV RMSE=38.782, Test R2=0.078
# MLP Medium: CV RMSE=37.084, Test R2=0.103
# MLP Large: CV RMSE=54.868, Test R2=-0.677
# --> Added CatBoost to ensemble. New Test R2 = 0.8011
# --> Added Extra Trees to ensemble. New Test R2 = 0.8111
# --> Added Bagging Regressor to ensemble. New Test R2 = 0.8156
#
# Final Ensemble Models: ['CatBoost', 'Extra Trees', 'Bagging Regressor']
#
# Final Ensemble Test Performance: RMSE=24.093, MAE=14.882, R2=0.816
# ================ Horizon 1 Years ================
# Extra Trees: CV RMSE=13.044, Test R2=0.773
# Random Forest: CV RMSE=13.895, Test R2=0.780
# Gradient Boosting: CV RMSE=19.042, Test R2=0.656
# HistGradientBoosting: CV RMSE=15.090, Test R2=0.647
# IsolationForest: CV RMSE=106.236, Test R2=-3.811
# XGBoost: CV RMSE=13.349, Test R2=0.730
# CatBoost: CV RMSE=13.924, Test R2=0.793
# LightGBM: CV RMSE=15.224, Test R2=0.650
# Ridge Regression: CV RMSE=38.832, Test R2=0.065
# Lasso Regression: CV RMSE=38.865, Test R2=0.068
# Elastic Net: CV RMSE=38.865, Test R2=0.068
# KNN Regressor: CV RMSE=31.111, Test R2=0.241
# SVR RBF: CV RMSE=42.375, Test R2=-0.119
# SVR Linear: CV RMSE=42.519, Test R2=-0.123
# Bagging Regressor: CV RMSE=14.418, Test R2=0.774
# MLP Small: CV RMSE=37.680, Test R2=0.018
# MLP Medium: CV RMSE=37.124, Test R2=0.090
# MLP Large: CV RMSE=59.418, Test R2=0.004
# --> Added CatBoost to ensemble. New Test R2 = 0.7925
# --> Added Bagging Regressor to ensemble. New Test R2 = 0.8029
# --> Added Extra Trees to ensemble. New Test R2 = 0.8083
#
# Final Ensemble Models: ['CatBoost', 'Bagging Regressor', 'Extra Trees']
#
# Final Ensemble Test Performance: RMSE=24.561, MAE=15.238, R2=0.808
# ================ Horizon 2 Years ================
# Extra Trees: CV RMSE=12.910, Test R2=0.795
# Random Forest: CV RMSE=13.758, Test R2=0.776
# Gradient Boosting: CV RMSE=19.051, Test R2=0.631
# HistGradientBoosting: CV RMSE=14.969, Test R2=0.642
# IsolationForest: CV RMSE=106.224, Test R2=-3.812
# XGBoost: CV RMSE=13.435, Test R2=0.736
# CatBoost: CV RMSE=13.975, Test R2=0.789
# LightGBM: CV RMSE=15.054, Test R2=0.619
# Ridge Regression: CV RMSE=38.823, Test R2=0.064
# Lasso Regression: CV RMSE=38.865, Test R2=0.066
# Elastic Net: CV RMSE=38.864, Test R2=0.066
# KNN Regressor: CV RMSE=30.579, Test R2=0.242
# SVR RBF: CV RMSE=42.357, Test R2=-0.119
# SVR Linear: CV RMSE=42.486, Test R2=-0.124
# Bagging Regressor: CV RMSE=14.934, Test R2=0.760
# MLP Small: CV RMSE=37.912, Test R2=0.111
# MLP Medium: CV RMSE=36.914, Test R2=0.098
# MLP Large: CV RMSE=44.240, Test R2=0.047
# --> Added Extra Trees to ensemble. New Test R2 = 0.7947
# --> Added Random Forest to ensemble. New Test R2 = 0.8101
# --> Added CatBoost to ensemble. New Test R2 = 0.8111
#
# Final Ensemble Models: ['Extra Trees', 'Random Forest', 'CatBoost']
#
# Final Ensemble Test Performance: RMSE=24.381, MAE=14.311, R2=0.811
# ================ Horizon 5 Years ================
# Extra Trees: CV RMSE=13.269, Test R2=0.790
# Random Forest: CV RMSE=13.472, Test R2=0.771
# Gradient Boosting: CV RMSE=19.479, Test R2=0.625
# HistGradientBoosting: CV RMSE=14.989, Test R2=0.631
# IsolationForest: CV RMSE=106.217, Test R2=-3.813
# XGBoost: CV RMSE=14.578, Test R2=0.733
# CatBoost: CV RMSE=14.608, Test R2=0.771
# LightGBM: CV RMSE=15.097, Test R2=0.631
# Ridge Regression: CV RMSE=38.823, Test R2=0.066
# Lasso Regression: CV RMSE=38.865, Test R2=0.069
# Elastic Net: CV RMSE=38.865, Test R2=0.069
# KNN Regressor: CV RMSE=30.324, Test R2=0.333
# SVR RBF: CV RMSE=42.368, Test R2=-0.118
# SVR Linear: CV RMSE=42.490, Test R2=-0.124
# Bagging Regressor: CV RMSE=14.344, Test R2=0.750
# MLP Small: CV RMSE=38.781, Test R2=0.034
# MLP Medium: CV RMSE=37.266, Test R2=0.081
# MLP Large: CV RMSE=69.982, Test R2=0.110
# --> Added Extra Trees to ensemble. New Test R2 = 0.7898
# --> Added Random Forest to ensemble. New Test R2 = 0.8045
#
# Final Ensemble Models: ['Extra Trees', 'Random Forest']
#
# Final Ensemble Test Performance: RMSE=24.805, MAE=14.602, R2=0.804

# %% [markdown]
# ## finetuning models with selected features

# %%
# Main script for proposed model learning with tuning
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_predict, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import ExtraTreesRegressor, BaggingRegressor
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import RandomizedSearchCV

# Configuration
horizons = [0, 1, 2, 5]
features = ['Longitude','PFG_surface_pressure','Latitude','Slope','Elevation','Year','EVI']
target = 'ALT_Max'

# Load and evaluate
for hrz in horizons:
    print(f'\n*********************** HRZ = {hrz} years')
    train_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    test_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    train_info = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv', usecols=['MainRegion', 'Region', 'Location', 'Latitude', 'Longitude', 'Year'])
    test_info = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv', usecols=['MainRegion', 'Region', 'Location', 'Latitude', 'Longitude', 'Year'])

    train_data = train_data[features + [target]]
    test_data = test_data[features + [target]]

    X_train = train_data.drop(columns=target)
    y_train = train_data[target]
    X_test = test_data.drop(columns=target)
    y_test = test_data[target]

    print("- Tuning Extra Trees...")
    et_model = ExtraTreesRegressor(random_state=42)
    et_params = {
        'n_estimators': [300, 500, 1000, 1500, 2000, 2500],
        'max_depth': [None, 5, 7, 10, 20, 30, 50],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4, 6],
        'max_features': ['sqrt', 'log2', 0.5, 0.7, 0.9]
    }
    et_search = RandomizedSearchCV(et_model, et_params, n_iter=500, cv=cv, scoring='neg_root_mean_squared_error', random_state=42, n_jobs=-1)
    et_search.fit(X_train, y_train)
    best_et = et_search.best_estimator_
    print(f"  Best ExtraTrees: {et_search.best_params_}")

    print("- Tuning Bagging Regressor...")
    bag_model = BaggingRegressor(random_state=42)
    bag_params = {
        'n_estimators': [300, 500, 1000, 1500, 2000, 2500],
        'max_samples': [0.6, 0.7, 0.8, 0.9, 1.0],
        'max_features': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'bootstrap_features': [True, False]
    }
    bag_search = RandomizedSearchCV(bag_model, bag_params, n_iter=500, cv=cv, scoring='neg_root_mean_squared_error', random_state=42, n_jobs=-1)
    bag_search.fit(X_train, y_train)
    best_bag = bag_search.best_estimator_
    print(f"  Best Bagging: {bag_search.best_params_}")

    # Define CatBoost model
    cat_model = CatBoostRegressor(
        loss_function='RMSE',
        random_seed=42,
        verbose=0
    )

    # Create training Pool
    train_pool = Pool(X_train, y_train)

    # Parameter search space
    param_grid = {
        'iterations': [300, 500, 1000, 1500, 2000, 2500],
        'learning_rate': [0.01, 0.03, 0.05, 0.1],
        'depth': [4, 6, 8, 10],
        'l2_leaf_reg': [1, 3, 5, 7, 9],
        'bagging_temperature': [0, 1, 5],
        'random_strength': [1, 5, 10]
    }

    # Native grid search (CatBoost’s own)
    grid_result = cat_model.randomized_search(
        param_grid,
        X= X_train,
        y= y_train,
        cv=5,
        partition_random_seed=42,
        shuffle=True,
        refit=True,
        verbose=False,
        n_iter=500,
    )

    print(f"  Best Catboost: {grid_result['params']}")
    # Best CatBoost model after tuning
    best_cat = cat_model

    # Step 1: Define Models
    models = [
        ('Extra Trees', best_et),
        ('Bagging Regressor', best_bag),
        ('CatBoost',best_cat)
    ]

    preds_test = {}
    preds_train_cv = {}
    rmse_scores = {}

    # Step 2: CV predictions and RMSE
    for name, model in models:
        y_pred_cv = cross_val_predict(model, X_train, y_train, cv=cv, n_jobs=-1)
        model.fit(X_train, y_train)
        y_pred_test = model.predict(X_test)

        preds_test[name] = y_pred_test
        preds_train_cv[name] = y_pred_cv

        rmse = np.sqrt(mean_squared_error(y_train, y_pred_cv))
        r2 = r2_score(y_train, y_pred_cv)
        rmse_scores[name] = rmse

        print(f"{name}: CV Training RMSE = {rmse:.3f}, R²={r2:.3f} | Testing RMSE={np.sqrt(mean_squared_error(y_test, y_pred_test)):.3f}, R²={r2_score(y_test, y_pred_test):.3f}")

    # Step 3: Compute CV-based weights
    inverse_rmse = {k: 1 / v for k, v in rmse_scores.items()}
    total_inv = sum(inverse_rmse.values())
    weights = {k: v / total_inv for k, v in inverse_rmse.items()}

    # Step 4: Weighted predictions
    weighted_test_pred = sum(preds_test[m] * weights[m] for m in weights)
    weighted_cv_pred = sum(preds_train_cv[m] * weights[m] for m in weights)

    # Step 5: Evaluate weighted ensemble
    rmse = np.sqrt(mean_squared_error(y_test, weighted_test_pred))
    mae = mean_absolute_error(y_test, weighted_test_pred)
    r2 = r2_score(y_test, weighted_test_pred)
    print(f"==> Weighted Ensemble - RMSE: {rmse:.3f}, MAE: {mae:.3f}, R²: {r2:.3f}")

    # Step 6: Build outputs with metadata
    train_info = train_info.reset_index(drop=True)
    test_info = test_info.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    df_train_out = train_info.copy()
    df_test_out = test_info.copy()

    df_train_out['y_train'] = y_train
    df_test_out['y_test'] = y_test

    for name in preds_train_cv:
        df_train_out[f'y_trpred_{name}'] = preds_train_cv[name]
        df_test_out[f'y_tepred_{name}'] = preds_test[name]
        df_train_out[f'weight_{name}'] = weights[name]
        df_test_out[f'weight_{name}'] = weights[name]

    df_train_out['y_trpred_ensemble'] = weighted_cv_pred
    df_train_out['weight_ensemble'] = 1.0
    df_test_out['y_tepred_ensemble'] = weighted_test_pred
    df_test_out['weight_ensemble'] = 1.0

    # Save if needed
    df_train_out.to_csv(f'/content/drive/MyDrive/UND/ALT/ALT_hrz{hrz}_TrainPredictions.csv', index=False)
    df_test_out.to_csv(f'/content/drive/MyDrive/UND/ALT/ALT_hrz{hrz}_TestPredictions.csv', index=False)
# Out:
# *********************** HRZ = 0 years
# - Tuning Extra Trees...
# /usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
#   Best ExtraTrees: {'n_estimators': 901, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': None}
# - Tuning Bagging Regressor...
#   Best Bagging: {'n_estimators': 2367, 'max_samples': 1.0, 'max_features': 1.0, 'bootstrap_features': False}
#
# bestTest = 22.59740196
# bestIteration = 102
#
#
# bestTest = 20.91807541
# bestIteration = 147
#
#
# bestTest = 16.9647639
# bestIteration = 207
#
#
# bestTest = 13.19485159
# bestIteration = 601
#
#
# bestTest = 21.31507923
# bestIteration = 775
#
#
# bestTest = 15.76711526
# bestIteration = 893
#
#
# bestTest = 19.07715095
# bestIteration = 928
#
#
# bestTest = 15.50702748
# bestIteration = 946
#
#
# bestTest = 18.64587757
# bestIteration = 1279
#
#
# bestTest = 12.20937782
# bestIteration = 1354
#
#
# bestTest = 12.81696159
# bestIteration = 2054
#
#
# bestTest = 13.13668544
# bestIteration = 2270
#
#
# bestTest = 17.56680511
# bestIteration = 2387
#
#
# bestTest = 23.91630813
# bestIteration = 66
#
#
# bestTest = 20.8287443
# bestIteration = 95
#
#
# bestTest = 17.60866424
# bestIteration = 556
#
#
# bestTest = 13.17893477
# bestIteration = 753
#
#
# bestTest = 14.18056915
# bestIteration = 953
#
#
# bestTest = 16.12602923
# bestIteration = 1008
#
#
# bestTest = 20.32126341
# bestIteration = 1188
#
#
# bestTest = 12.34503627
# bestIteration = 1192
#
#
# bestTest = 14.84092376
# bestIteration = 1355
#
#
# bestTest = 13.85440753
# bestIteration = 1372
#
#
# bestTest = 12.40831233
# bestIteration = 1759
#
#
# bestTest = 12.47610491
# bestIteration = 1941
#
#
# bestTest = 18.91004671
# bestIteration = 1968
#
#
# bestTest = 40.29282907
# bestIteration = 156
#
#
# bestTest = 23.28734649
# bestIteration = 163
#
#
# bestTest = 19.51128209
# bestIteration = 327
#
#
# bestTest = 14.14671312
# bestIteration = 777
#
#
# bestTest = 21.2120346
# bestIteration = 1171
#
#
# bestTest = 12.68484434
# bestIteration = 1196
#
#
# bestTest = 12.34980169
# bestIteration = 1242
#
#
# bestTest = 18.14922101
# bestIteration = 1998
#
#
# bestTest = 12.12809394
# bestIteration = 2130
#
#
# bestTest = 12.66688214
# bestIteration = 2301
#
#
# bestTest = 17.94265197
# bestIteration = 84
#
#
# bestTest = 15.19131919
# bestIteration = 496
#
#
# bestTest = 13.52859908
# bestIteration = 596
#
#
# bestTest = 13.70664803
# bestIteration = 614
#
#
# bestTest = 12.13067873
# bestIteration = 956
#
#
# bestTest = 16.61902429
# bestIteration = 978
#
#
# bestTest = 13.17175798
# bestIteration = 1052
#
#
# bestTest = 12.814441
# bestIteration = 1224
#
#
# bestTest = 16.46452058
# bestIteration = 1272
#
#
# bestTest = 12.30293513
# bestIteration = 1209
#
#
# bestTest = 16.26545995
# bestIteration = 1346
#
#
# bestTest = 12.81228002
# bestIteration = 1369
#
#
# bestTest = 12.36995916
# bestIteration = 1404
#
#
# bestTest = 12.29758864
# bestIteration = 1390
#
#
# bestTest = 12.67829789
# bestIteration = 1515
#
#
# bestTest = 12.8521756
# bestIteration = 1621
#
#
# bestTest = 12.53308802
# bestIteration = 1583
#
#
# bestTest = 14.21856514
# bestIteration = 1873
#
#
# bestTest = 12.48775766
# bestIteration = 1147
#
#
# bestTest = 12.41562967
# bestIteration = 2078
#
#
# bestTest = 12.44786085
# bestIteration = 2287
#
#
# bestTest = 12.08103953
# bestIteration = 1578
#
#
# bestTest = 14.25236066
# bestIteration = 2355
#
#
# bestTest = 12.08103953
# bestIteration = 1578
#
#
# bestTest = 12.35947228
# bestIteration = 2450
#
#
# bestTest = 14.0810416
# bestIteration = 2497
#
#
# bestTest = 21.29548691
# bestIteration = 144
#
#
# bestTest = 16.29950042
# bestIteration = 443
#
#
# bestTest = 13.57283641
# bestIteration = 572
#
#
# bestTest = 12.83774555
# bestIteration = 628
#
#
# bestTest = 14.23364723
# bestIteration = 958
#
#
# bestTest = 13.06664613
# bestIteration = 1070
#
#
# bestTest = 12.55445864
# bestIteration = 1304
#
#
# bestTest = 13.28729227
# bestIteration = 1460
#
#
# bestTest = 13.19421803
# bestIteration = 1519
#
#
# bestTest = 13.90143367
# bestIteration = 2019
#
#
# bestTest = 12.31953486
# bestIteration = 2131
#
#
# bestTest = 12.42890762
# bestIteration = 1766
#
#
# bestTest = 12.61174483
# bestIteration = 2493
#
#
# bestTest = 15.33121267
# bestIteration = 267
#
#
# bestTest = 24.83687122
# bestIteration = 437
#
#
# bestTest = 16.4196119
# bestIteration = 787
#
#
# bestTest = 13.15732923
# bestIteration = 824
#
#
# bestTest = 19.76344835
# bestIteration = 1002
#
#
# bestTest = 12.50969957
# bestIteration = 1075
#
#
# bestTest = 12.85621952
# bestIteration = 1173
#
#
# bestTest = 12.66156711
# bestIteration = 1355
#
#
# bestTest = 12.46319418
# bestIteration = 1808
#
#
# bestTest = 12.48594595
# bestIteration = 852
#
#
# bestTest = 14.84969344
# bestIteration = 2305
#
#
# bestTest = 15.9155919
# bestIteration = 199
#
#
# bestTest = 14.55789862
# bestIteration = 298
#
#
# bestTest = 12.88686027
# bestIteration = 395
#
#
# bestTest = 12.82551187
# bestIteration = 430
#
#
# bestTest = 15.26262252
# bestIteration = 499
#
#
# bestTest = 12.62124363
# bestIteration = 929
#
#
# bestTest = 12.50338524
# bestIteration = 749
#
#
# bestTest = 12.18990713
# bestIteration = 1254
#
#
# bestTest = 12.53131805
# bestIteration = 1317
#
#
# bestTest = 12.94184386
# bestIteration = 1381
#
#
# bestTest = 12.82367203
# bestIteration = 530
#
#
# bestTest = 12.14580906
# bestIteration = 1885
#
#
# bestTest = 12.82367203
# bestIteration = 530
#
#
# bestTest = 17.99813086
# bestIteration = 82
#
#
# bestTest = 21.73924672
# bestIteration = 126
#
#
# bestTest = 12.88663949
# bestIteration = 438
#
#
# bestTest = 17.0738732
# bestIteration = 479
#
#
# bestTest = 17.87493785
# bestIteration = 1009
#
#
# bestTest = 12.60585381
# bestIteration = 1136
#
#
# bestTest = 12.39569902
# bestIteration = 757
#
#
# bestTest = 12.79197438
# bestIteration = 1470
#
#
# bestTest = 13.70203453
# bestIteration = 1485
#
#
# bestTest = 15.34313857
# bestIteration = 1802
#
#
# bestTest = 12.45816418
# bestIteration = 1440
#
#
# bestTest = 12.52768937
# bestIteration = 1752
#
#
# bestTest = 12.34734059
# bestIteration = 2151
#
#
# bestTest = 12.3820381
# bestIteration = 2242
#
#
# bestTest = 12.55163366
# bestIteration = 1375
#
#
# bestTest = 13.68099602
# bestIteration = 2348
#
#
# bestTest = 12.40131711
# bestIteration = 2208
#
#
# bestTest = 19.31156743
# bestIteration = 208
#
#
# bestTest = 15.45162219
# bestIteration = 227
#
#
# bestTest = 15.33914574
# bestIteration = 522
#
#
# bestTest = 12.92567255
# bestIteration = 528
#
#
# bestTest = 12.68887956
# bestIteration = 701
#
#
# bestTest = 13.09149487
# bestIteration = 796
#
#
# bestTest = 12.56803539
# bestIteration = 851
#
#
# bestTest = 12.71768387
# bestIteration = 895
#
#
# bestTest = 17.31675438
# bestIteration = 1135
#
#
# bestTest = 12.26707068
# bestIteration = 1189
#
#
# bestTest = 12.40114608
# bestIteration = 1336
#
#
# bestTest = 12.82128812
# bestIteration = 1444
#
#
# bestTest = 12.68694288
# bestIteration = 863
#
#
# bestTest = 12.37229396
# bestIteration = 1536
#
#
# bestTest = 12.29510438
# bestIteration = 1940
#
#
# bestTest = 12.37229396
# bestIteration = 1536
#
#
# bestTest = 15.83712473
# bestIteration = 145
#
#
# bestTest = 15.95263344
# bestIteration = 216
#
#
# bestTest = 14.33593757
# bestIteration = 255
#
#
# bestTest = 12.59825335
# bestIteration = 641
#
#
# bestTest = 13.29963956
# bestIteration = 1075
#
#
# bestTest = 13.80453934
# bestIteration = 1212
#
#
# bestTest = 14.51968647
# bestIteration = 1259
#
#
# bestTest = 12.32135079
# bestIteration = 381
#
#
# bestTest = 12.32135079
# bestIteration = 381
#
#
# bestTest = 14.36749532
# bestIteration = 2305
#
#
# bestTest = 12.53349755
# bestIteration = 1963
#
#
# bestTest = 14.34599085
# bestIteration = 2327
#
#
# bestTest = 23.63223497
# bestIteration = 247
#
#
# bestTest = 21.05985026
# bestIteration = 375
#
#
# bestTest = 13.21800213
# bestIteration = 532
#
#
# bestTest = 12.36689407
# bestIteration = 729
#
#
# bestTest = 14.96881625
# bestIteration = 860
#
#
# bestTest = 12.69757221
# bestIteration = 1154
#
#
# bestTest = 15.77207738
# bestIteration = 1224
#
#
# bestTest = 12.6754199
# bestIteration = 2067
#
#
# bestTest = 14.99034918
# bestIteration = 183
#
#
# bestTest = 21.54910709
# bestIteration = 346
#
#
# bestTest = 12.60112018
# bestIteration = 603
#
#
# bestTest = 18.02672702
# bestIteration = 659
#
#
# bestTest = 12.85254445
# bestIteration = 786
#
#
# bestTest = 12.72652775
# bestIteration = 842
#
#
# bestTest = 12.62134583
# bestIteration = 933
#
#
# bestTest = 12.92741638
# bestIteration = 597
#
#
# bestTest = 16.29796169
# bestIteration = 1164
#
#
# bestTest = 12.69208772
# bestIteration = 1006
#
#
# bestTest = 14.99985295
# bestIteration = 1346
#
#
# bestTest = 12.46385151
# bestIteration = 2339
#
#
# bestTest = 12.56301841
# bestIteration = 2490
#
#
# bestTest = 24.65687949
# bestIteration = 124
#
#
# bestTest = 18.70591661
# bestIteration = 197
#
#
# bestTest = 15.69233918
# bestIteration = 218
#
#
# bestTest = 26.34832574
# bestIteration = 294
#
#
# bestTest = 18.84040333
# bestIteration = 379
#
#
# bestTest = 17.30994684
# bestIteration = 411
#
#
# bestTest = 14.31753168
# bestIteration = 846
#
#
# bestTest = 21.16307451
# bestIteration = 910
#
#
# bestTest = 12.24928636
# bestIteration = 1000
#
#
# bestTest = 12.44264257
# bestIteration = 1093
#
#
# bestTest = 24.64525736
# bestIteration = 59
#
#
# bestTest = 21.80355359
# bestIteration = 322
#
#
# bestTest = 21.40326775
# bestIteration = 885
#
#
# bestTest = 12.75176411
# bestIteration = 930
#
#
# bestTest = 12.48577037
# bestIteration = 1324
#
#
# bestTest = 12.45138739
# bestIteration = 1385
#
#
# bestTest = 12.52308164
# bestIteration = 1465
#
#
# bestTest = 18.04518322
# bestIteration = 1684
#
#
# bestTest = 14.08393395
# bestIteration = 1937
#
#
# bestTest = 12.60376706
# bestIteration = 1880
#
#
# bestTest = 12.74898914
# bestIteration = 2445
#
#
# bestTest = 26.96171719
# bestIteration = 82
#
#
# bestTest = 15.21583313
# bestIteration = 663
#
#
# bestTest = 13.68820123
# bestIteration = 674
#
#
# bestTest = 15.3405536
# bestIteration = 1280
#
#
# bestTest = 12.85986977
# bestIteration = 1299
#
#
# bestTest = 14.10115357
# bestIteration = 1438
#
#
# bestTest = 13.24600436
# bestIteration = 1590
#
#
# bestTest = 12.29479272
# bestIteration = 1769
#
#
# bestTest = 52.8252639
# bestIteration = 86
#
#
# bestTest = 16.05127221
# bestIteration = 266
#
#
# bestTest = 18.58999779
# bestIteration = 307
#
#
# bestTest = 12.57813491
# bestIteration = 342
#
#
# bestTest = 13.38515162
# bestIteration = 716
#
#
# bestTest = 13.70818152
# bestIteration = 785
#
#
# bestTest = 12.37289054
# bestIteration = 427
#
#
# bestTest = 14.56808141
# bestIteration = 958
#
#
# bestTest = 15.37476821
# bestIteration = 1026
#
#
# bestTest = 13.34647918
# bestIteration = 1364
#
#
# bestTest = 16.80881674
# bestIteration = 1427
#
#
# bestTest = 12.28245757
# bestIteration = 1557
#
#
# bestTest = 12.35219198
# bestIteration = 1589
#
#
# bestTest = 12.66882185
# bestIteration = 1793
#
#
# bestTest = 15.5767877
# bestIteration = 1886
#
#
# bestTest = 12.53308802
# bestIteration = 1583
#
#
# bestTest = 13.3492079
# bestIteration = 2132
#
#
# bestTest = 12.65371047
# bestIteration = 2224
#
#
# bestTest = 12.48775766
# bestIteration = 1147
#
#
# bestTest = 12.60148144
# bestIteration = 2435
#
#
# bestTest = 13.26133796
# bestIteration = 450
#
#
# bestTest = 16.12537335
# bestIteration = 591
#
#
# bestTest = 20.85454921
# bestIteration = 713
#
#
# bestTest = 20.35878019
# bestIteration = 726
#
#
# bestTest = 12.6103587
# bestIteration = 770
#
#
# bestTest = 15.1778706
# bestIteration = 823
#
#
# bestTest = 13.63385054
# bestIteration = 902
#
#
# bestTest = 19.28319287
# bestIteration = 1118
#
#
# bestTest = 12.53567002
# bestIteration = 1106
#
#
# bestTest = 12.4901717
# bestIteration = 1249
#
#
# bestTest = 13.06650636
# bestIteration = 1618
#
#
# bestTest = 12.85025679
# bestIteration = 1768
#
#
# bestTest = 15.57799552
# bestIteration = 1884
#
#
# bestTest = 12.64558851
# bestIteration = 1933
#
#
# bestTest = 13.72780715
# bestIteration = 2470
#
#
# bestTest = 21.38337125
# bestIteration = 77
#
#
# bestTest = 29.91559895
# bestIteration = 85
#
#
# bestTest = 22.30725571
# bestIteration = 143
#
#
# bestTest = 18.0110054
# bestIteration = 392
#
#
# bestTest = 14.58853664
# bestIteration = 736
#
#
# bestTest = 12.61810967
# bestIteration = 757
#
#
# bestTest = 12.41177337
# bestIteration = 892
#
#
# bestTest = 12.82369486
# bestIteration = 1058
#
#
# bestTest = 12.91779103
# bestIteration = 1089
#
#
# bestTest = 19.4912984
# bestIteration = 1134
#
#
# bestTest = 12.97760034
# bestIteration = 1166
#
#
# bestTest = 15.5704839
# bestIteration = 1357
#
#
# bestTest = 18.26224676
# bestIteration = 1607
#
#
# bestTest = 17.25726796
# bestIteration = 1669
#
#
# bestTest = 12.44979151
# bestIteration = 1333
#
#
# bestTest = 12.41314514
# bestIteration = 2003
#
#
# bestTest = 12.64490168
# bestIteration = 1163
#
#
# bestTest = 12.6261097
# bestIteration = 2363
#
#
# bestTest = 41.76133487
# bestIteration = 134
#
#
# bestTest = 13.47951688
# bestIteration = 755
#
#
# bestTest = 13.74422315
# bestIteration = 900
#
#
# bestTest = 12.42766574
# bestIteration = 865
#
#
# bestTest = 12.50338524
# bestIteration = 749
#
#
# bestTest = 15.79871604
# bestIteration = 1295
#
#
# bestTest = 12.59922468
# bestIteration = 1695
#
#
# bestTest = 12.35848747
# bestIteration = 1724
#
#
# bestTest = 12.41459951
# bestIteration = 2048
#
#
# bestTest = 12.24460486
# bestIteration = 2198
#
#
# bestTest = 17.343247
# bestIteration = 221
#
#
# bestTest = 15.1309889
# bestIteration = 395
#
#
# bestTest = 12.58867247
# bestIteration = 427
#
#
# bestTest = 16.52995762
# bestIteration = 538
#
#
# bestTest = 13.58718948
# bestIteration = 592
#
#
# bestTest = 14.51805455
# bestIteration = 715
#
#
# bestTest = 12.5366661
# bestIteration = 857
#
#
# bestTest = 12.8482599
# bestIteration = 925
#
#
# bestTest = 12.52807325
# bestIteration = 1713
#
#
# bestTest = 13.20783017
# bestIteration = 1861
#
#
# bestTest = 12.30019712
# bestIteration = 1754
#
#
# bestTest = 13.47267851
# bestIteration = 2087
#
#
# bestTest = 12.56819832
# bestIteration = 566
#
#
# bestTest = 16.94054206
# bestIteration = 308
#
#
# bestTest = 19.23729548
# bestIteration = 542
#
#
# bestTest = 12.69431954
# bestIteration = 698
#
#
# bestTest = 15.59757971
# bestIteration = 1030
#
#
# bestTest = 12.48609448
# bestIteration = 1025
#
#
# bestTest = 12.50251803
# bestIteration = 1233
#
#
# bestTest = 12.68694288
# bestIteration = 863
#
#
# bestTest = 12.32180707
# bestIteration = 1507
#
#
# bestTest = 12.68694288
# bestIteration = 863
#
#
# bestTest = 13.96440141
# bestIteration = 70
#
#
# bestTest = 13.3304264
# bestIteration = 298
#
#
# bestTest = 13.39458298
# bestIteration = 311
#
#
# bestTest = 14.68222522
# bestIteration = 367
#
#
# bestTest = 12.88000393
# bestIteration = 480
#
#
# bestTest = 12.5035015
# bestIteration = 495
#
#
# bestTest = 16.10235308
# bestIteration = 565
#
#
# bestTest = 15.88512788
# bestIteration = 729
#
#
# bestTest = 15.04753951
# bestIteration = 750
#
#
# bestTest = 12.49665359
# bestIteration = 958
#
#
# bestTest = 12.5696196
# bestIteration = 1472
#
#
# bestTest = 12.79836318
# bestIteration = 1483
#
#
# bestTest = 12.44283742
# bestIteration = 1144
#
#
# bestTest = 12.85185026
# bestIteration = 701
#
#
# bestTest = 12.72477403
# bestIteration = 962
#
#
# bestTest = 12.26101258
# bestIteration = 1698
#
#
# bestTest = 12.52185809
# bestIteration = 1327
#
#
# bestTest = 12.59506776
# bestIteration = 1879
#
#
# bestTest = 14.27041834
# bestIteration = 1914
#
#
# bestTest = 12.52185809
# bestIteration = 1327
#
#
# bestTest = 13.79081109
# bestIteration = 2288
#
#
# bestTest = 15.8313771
# bestIteration = 177
#
#
# bestTest = 14.76796133
# bestIteration = 181
#
#
# bestTest = 12.58753366
# bestIteration = 458
#
#
# bestTest = 13.9345536
# bestIteration = 460
#
#
# bestTest = 14.3380142
# bestIteration = 532
#
#
# bestTest = 12.92902852
# bestIteration = 547
#
#
# bestTest = 12.3838043
# bestIteration = 563
#
#
# bestTest = 17.83974168
# bestIteration = 660
#
#
# bestTest = 12.57999765
# bestIteration = 676
#
#
# bestTest = 15.90557909
# bestIteration = 815
#
#
# bestTest = 12.62776159
# bestIteration = 1258
#
#
# bestTest = 16.27780044
# bestIteration = 1289
#
#
# bestTest = 12.57847014
# bestIteration = 1382
#
#
# bestTest = 12.50804347
# bestIteration = 1527
#
#
# bestTest = 12.58182062
# bestIteration = 697
#
#
# bestTest = 12.65374617
# bestIteration = 1842
#
#
# bestTest = 12.45875345
# bestIteration = 1960
#
#
# bestTest = 12.58182062
# bestIteration = 697
#
#
# bestTest = 12.32567203
# bestIteration = 1246
#
#
# bestTest = 21.67929075
# bestIteration = 368
#
#
# bestTest = 16.34352103
# bestIteration = 729
#
#
# bestTest = 12.71424521
# bestIteration = 856
#
#
# bestTest = 13.83806374
# bestIteration = 963
#
#
# bestTest = 12.53150948
# bestIteration = 993
#
#
# bestTest = 12.73277669
# bestIteration = 771
#
#
# bestTest = 16.32865064
# bestIteration = 1145
#
#
# bestTest = 12.69208772
# bestIteration = 1006
#
#
# bestTest = 12.73179063
# bestIteration = 1713
#
#
# bestTest = 12.48570202
# bestIteration = 1913
#
#
# bestTest = 12.6305464
# bestIteration = 1723
#
#
# bestTest = 12.73179063
# bestIteration = 1713
#
#
# bestTest = 12.58190335
# bestIteration = 2267
#
#
# bestTest = 14.72499289
# bestIteration = 445
#
#
# bestTest = 22.53430944
# bestIteration = 468
#
#
# bestTest = 12.84711032
# bestIteration = 687
#
#
# bestTest = 12.5481051
# bestIteration = 729
#
#
# bestTest = 20.14627988
# bestIteration = 885
#
#
# bestTest = 13.66042842
# bestIteration = 1122
#
#
# bestTest = 20.48476316
# bestIteration = 1190
#
#
# bestTest = 12.20937782
# bestIteration = 1354
#
#
# bestTest = 19.03999441
# bestIteration = 1475
#
#
# bestTest = 12.19595261
# bestIteration = 1707
#
#
# bestTest = 13.0792531
# bestIteration = 1742
#
#
# bestTest = 15.99664966
# bestIteration = 1985
#
#
# bestTest = 12.06660216
# bestIteration = 1998
#
#
# bestTest = 12.3267832
# bestIteration = 2220
#
#
# bestTest = 12.44973682
# bestIteration = 2445
#
#
# bestTest = 12.06660216
# bestIteration = 1998
#
#
# bestTest = 22.89746499
# bestIteration = 246
#
#
# bestTest = 28.21293431
# bestIteration = 349
#
#
# bestTest = 21.67261959
# bestIteration = 361
#
#
# bestTest = 14.12874881
# bestIteration = 401
#
#
# bestTest = 17.55312669
# bestIteration = 428
#
#
# bestTest = 17.31413493
# bestIteration = 583
#
#
# bestTest = 15.20280656
# bestIteration = 666
#
#
# bestTest = 13.97915134
# bestIteration = 1020
#
#
# bestTest = 15.1054247
# bestIteration = 1114
#
#
# bestTest = 15.23187291
# bestIteration = 1348
#
#
# bestTest = 12.4017888
# bestIteration = 1966
#
#
# bestTest = 12.60376706
# bestIteration = 1880
#
#
# bestTest = 42.44223311
# bestIteration = 140
#
#
# bestTest = 23.85718585
# bestIteration = 259
#
#
# bestTest = 19.03575402
# bestIteration = 519
#
#
# bestTest = 20.04794516
# bestIteration = 581
#
#
# bestTest = 15.20875897
# bestIteration = 664
#
#
# bestTest = 12.76080097
# bestIteration = 884
#
#
# bestTest = 13.99047782
# bestIteration = 959
#
#
# bestTest = 21.38134649
# bestIteration = 1073
#
#
# bestTest = 13.93419765
# bestIteration = 1081
#
#
# bestTest = 12.31775536
# bestIteration = 1390
#
#
# bestTest = 12.48293138
# bestIteration = 1417
#
#
# bestTest = 14.51340759
# bestIteration = 1843
#
#
# bestTest = 18.94975672
# bestIteration = 2002
#
#
# bestTest = 13.76684954
# bestIteration = 2290
#
#
# bestTest = 15.07828631
# bestIteration = 199
#
#
# bestTest = 12.56757402
# bestIteration = 946
#
#
# bestTest = 18.53933491
# bestIteration = 1090
#
#
# bestTest = 13.97514578
# bestIteration = 1188
#
#
# bestTest = 16.5102744
# bestIteration = 1257
#
#
# bestTest = 12.72608058
# bestIteration = 1886
#
#
# bestTest = 13.73430964
# bestIteration = 2255
#
#
# bestTest = 13.67963461
# bestIteration = 2320
#
#
# bestTest = 24.72034761
# bestIteration = 326
#
#
# bestTest = 14.72571941
# bestIteration = 397
#
#
# bestTest = 12.75979233
# bestIteration = 555
#
#
# bestTest = 20.45740959
# bestIteration = 630
#
#
# bestTest = 20.23676779
# bestIteration = 752
#
#
# bestTest = 13.68216504
# bestIteration = 888
#
#
# bestTest = 12.65129997
# bestIteration = 937
#
#
# bestTest = 12.6915325
# bestIteration = 960
#
#
# bestTest = 12.81665592
# bestIteration = 1095
#
#
# bestTest = 13.43043813
# bestIteration = 1621
#
#
# bestTest = 12.79878883
# bestIteration = 556
#
#
# bestTest = 17.80248014
# bestIteration = 126
#
#
# bestTest = 17.01102007
# bestIteration = 206
#
#
# bestTest = 13.90484485
# bestIteration = 222
#
#
# bestTest = 16.94869617
# bestIteration = 319
#
#
# bestTest = 13.61078984
# bestIteration = 411
#
#
# bestTest = 19.00570146
# bestIteration = 417
#
#
# bestTest = 16.21917364
# bestIteration = 587
#
#
# bestTest = 22.72094516
# bestIteration = 595
#
#
# bestTest = 13.60766502
# bestIteration = 797
#
#
# bestTest = 12.66294055
# bestIteration = 632
#
#
# bestTest = 19.42323249
# bestIteration = 990
#
#
# bestTest = 12.6654857
# bestIteration = 1093
#
#
# bestTest = 18.2615175
# bestIteration = 1177
#
#
# bestTest = 13.5158602
# bestIteration = 1267
#
#
# bestTest = 18.41645629
# bestIteration = 1330
#
#
# bestTest = 13.14256446
# bestIteration = 1418
#
#
# bestTest = 12.66294055
# bestIteration = 632
#
#
# bestTest = 12.75079817
# bestIteration = 1729
#
#
# bestTest = 12.60082409
# bestIteration = 1764
#
#
# bestTest = 12.51943367
# bestIteration = 1947
#
#
# bestTest = 12.51805619
# bestIteration = 2270
#
#
# bestTest = 12.44705192
# bestIteration = 2303
#
#
# bestTest = 13.49948351
# bestIteration = 2466
#
#
# bestTest = 19.9422827
# bestIteration = 64
#
#
# bestTest = 26.96785274
# bestIteration = 244
#
#
# bestTest = 12.69855767
# bestIteration = 348
#
#
# bestTest = 16.99938769
# bestIteration = 360
#
#
# bestTest = 12.50779686
# bestIteration = 458
#
#
# bestTest = 15.35580558
# bestIteration = 478
#
#
# bestTest = 14.35931526
# bestIteration = 1222
#
#
# bestTest = 12.42766574
# bestIteration = 865
#
#
# bestTest = 12.29894071
# bestIteration = 1367
#
#
# bestTest = 12.68589485
# bestIteration = 664
#
#
# bestTest = 12.28966131
# bestIteration = 1725
#
#
# bestTest = 12.24405209
# bestIteration = 1759
#
#
# bestTest = 12.24405209
# bestIteration = 1759
#
#
# bestTest = 12.69550694
# bestIteration = 2066
#
#
# bestTest = 12.28777261
# bestIteration = 2360
#
#
# bestTest = 12.35848747
# bestIteration = 1724
#
#
# bestTest = 12.35029946
# bestIteration = 2422
#
#
# bestTest = 12.60291256
# bestIteration = 364
#
#
# bestTest = 13.91521331
# bestIteration = 439
#
#
# bestTest = 19.67461963
# bestIteration = 441
#
#
# bestTest = 18.75224183
# bestIteration = 763
#
#
# bestTest = 17.20641857
# bestIteration = 802
#
#
# bestTest = 12.5366661
# bestIteration = 857
#
#
# bestTest = 18.30288965
# bestIteration = 859
#
#
# bestTest = 12.30081139
# bestIteration = 1090
#
#
# bestTest = 12.2883803
# bestIteration = 1144
#
#
# bestTest = 12.64686026
# bestIteration = 1607
#
#
# bestTest = 12.30019712
# bestIteration = 1754
#
#
# bestTest = 12.33252551
# bestIteration = 1871
#
#
# bestTest = 12.30019712
# bestIteration = 1754
#
#
# bestTest = 12.39569902
# bestIteration = 757
#
#
# bestTest = 12.42035578
# bestIteration = 1255
#
#
# bestTest = 71.94748473
# bestIteration = 49
#
#
# bestTest = 28.41650865
# bestIteration = 71
#
#
# bestTest = 12.5251081
# bestIteration = 411
#
#
# bestTest = 12.86973424
# bestIteration = 524
#
#
# bestTest = 18.44903174
# bestIteration = 715
#
#
# bestTest = 12.49486914
# bestIteration = 1017
#
#
# bestTest = 17.38069697
# bestIteration = 1088
#
#
# bestTest = 12.65131006
# bestIteration = 1287
#
#
# bestTest = 12.36182106
# bestIteration = 1723
#
#
# bestTest = 14.91571396
# bestIteration = 2089
#
#
# bestTest = 12.14898051
# bestIteration = 2296
#
#
# bestTest = 12.59112328
# bestIteration = 856
#
#
# bestTest = 12.80912084
# bestIteration = 2421
#
#
# bestTest = 63.76475593
# bestIteration = 70
#
#
# bestTest = 36.8058831
# bestIteration = 172
#
#
# bestTest = 15.06347699
# bestIteration = 363
#
#
# bestTest = 12.6068262
# bestIteration = 762
#
#
# bestTest = 15.99473197
# bestIteration = 824
#
#
# bestTest = 15.06292554
# bestIteration = 985
#
#
# bestTest = 14.59708685
# bestIteration = 1203
#
#
# bestTest = 12.44138135
# bestIteration = 1460
#
#
# bestTest = 12.67559212
# bestIteration = 764
#
#
# bestTest = 12.44138135
# bestIteration = 1460
#
#
# bestTest = 12.72477403
# bestIteration = 962
#
#
# bestTest = 12.67559212
# bestIteration = 764
#
#
# bestTest = 12.67559212
# bestIteration = 764
#
#
# bestTest = 12.73483564
# bestIteration = 445
#
#
# bestTest = 12.93733345
# bestIteration = 580
#
#
# bestTest = 17.04649771
# bestIteration = 793
#
#
# bestTest = 15.93322667
# bestIteration = 1133
#
#
# bestTest = 12.65714181
# bestIteration = 1643
#
#
# bestTest = 14.11907812
# bestIteration = 2140
#
#
# bestTest = 17.78391882
# bestIteration = 50
#
#
# bestTest = 65.18596031
# bestIteration = 67
#
#
# bestTest = 16.55045329
# bestIteration = 209
#
#
# bestTest = 13.94525262
# bestIteration = 261
#
#
# bestTest = 13.35291826
# bestIteration = 738
#
#
# bestTest = 12.45134959
# bestIteration = 939
#
#
# bestTest = 16.506513
# bestIteration = 1351
#
#
# bestTest = 14.87994046
# bestIteration = 1393
#
#
# bestTest = 12.45134959
# bestIteration = 939
#
#
# bestTest = 12.43405296
# bestIteration = 1587
#
#
# bestTest = 12.62597714
# bestIteration = 1648
#
#
# bestTest = 15.84814912
# bestIteration = 1742
#
#
# bestTest = 12.5895903
# bestIteration = 1857
#
#
# bestTest = 12.72316563
# bestIteration = 474
#
#
# bestTest = 12.47573385
# bestIteration = 2117
#
#
# bestTest = 15.10383321
# bestIteration = 2151
#
#
# bestTest = 12.92741638
# bestIteration = 597
#
#
# bestTest = 14.84323611
# bestIteration = 2298
#
#
# bestTest = 12.37440185
# bestIteration = 2389
#
#
# bestTest = 12.82197231
# bestIteration = 2432
#
# Training on fold [0/5]
#
# bestTest = 18.91206766
# bestIteration = 1981
#
# Training on fold [1/5]
#
# bestTest = 11.33948169
# bestIteration = 1912
#
# Training on fold [2/5]
#
# bestTest = 16.61059006
# bestIteration = 1627
#
# Training on fold [3/5]
#
# bestTest = 12.85829461
# bestIteration = 1663
#
# Training on fold [4/5]
#
# bestTest = 12.3316841
# bestIteration = 1926
#
#   Best Catboost: {'bagging_temperature': 5, 'random_strength': 1, 'depth': 4, 'learning_rate': 0.1, 'l2_leaf_reg': 5, 'iterations': 2001}
# Extra Trees: CV Training RMSE = 12.606, R²=0.909 | Testing RMSE=25.076, R²=0.800
# Bagging Regressor: CV Training RMSE = 13.049, R²=0.902 | Testing RMSE=26.350, R²=0.779
# CatBoost: CV Training RMSE = 13.125, R²=0.901 | Testing RMSE=27.624, R²=0.758
# ==> Weighted Ensemble - RMSE: 24.791, MAE: 14.915, R²: 0.805
#
# *********************** HRZ = 1 years
# - Tuning Extra Trees...
# /usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
#   Best ExtraTrees: {'n_estimators': 1594, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.7, 'max_depth': 50}
# - Tuning Bagging Regressor...
#   Best Bagging: {'n_estimators': 1877, 'max_samples': 1.0, 'max_features': 1.0, 'bootstrap_features': False}
#
# bestTest = 23.2001564
# bestIteration = 102
#
#
# bestTest = 21.42712946
# bestIteration = 147
#
#
# bestTest = 16.7186077
# bestIteration = 206
#
#
# bestTest = 13.1717608
# bestIteration = 601
#
#
# bestTest = 21.65720572
# bestIteration = 774
#
#
# bestTest = 16.25556563
# bestIteration = 893
#
#
# bestTest = 19.46532265
# bestIteration = 928
#
#
# bestTest = 15.98142295
# bestIteration = 946
#
#
# bestTest = 19.35233104
# bestIteration = 1279
#
#
# bestTest = 12.72095229
# bestIteration = 1353
#
#
# bestTest = 13.12611301
# bestIteration = 2053
#
#
# bestTest = 13.52746714
# bestIteration = 2270
#
#
# bestTest = 18.27627766
# bestIteration = 2387
#
#
# bestTest = 24.31602181
# bestIteration = 66
#
#
# bestTest = 21.28784099
# bestIteration = 95
#
#
# bestTest = 18.18137917
# bestIteration = 556
#
#
# bestTest = 13.56721459
# bestIteration = 753
#
#
# bestTest = 14.73570582
# bestIteration = 954
#
#
# bestTest = 16.82510252
# bestIteration = 1007
#
#
# bestTest = 20.76832145
# bestIteration = 1188
#
#
# bestTest = 12.74868181
# bestIteration = 1340
#
#
# bestTest = 15.27986951
# bestIteration = 1355
#
#
# bestTest = 14.38140767
# bestIteration = 1367
#
#
# bestTest = 12.52170596
# bestIteration = 1856
#
#
# bestTest = 13.04691176
# bestIteration = 1941
#
#
# bestTest = 19.58876868
# bestIteration = 1968
#
#
# bestTest = 41.02664051
# bestIteration = 156
#
#
# bestTest = 23.86633945
# bestIteration = 163
#
#
# bestTest = 20.32444033
# bestIteration = 327
#
#
# bestTest = 14.7013274
# bestIteration = 777
#
#
# bestTest = 22.0256375
# bestIteration = 1171
#
#
# bestTest = 12.72131955
# bestIteration = 1201
#
#
# bestTest = 12.22593906
# bestIteration = 1244
#
#
# bestTest = 19.43325899
# bestIteration = 1998
#
#
# bestTest = 12.38045556
# bestIteration = 1660
#
#
# bestTest = 13.00140564
# bestIteration = 2298
#
#
# bestTest = 18.27193274
# bestIteration = 83
#
#
# bestTest = 15.19038653
# bestIteration = 496
#
#
# bestTest = 13.58240701
# bestIteration = 596
#
#
# bestTest = 14.27743762
# bestIteration = 614
#
#
# bestTest = 13.00824044
# bestIteration = 956
#
#
# bestTest = 16.85364359
# bestIteration = 978
#
#
# bestTest = 13.08026214
# bestIteration = 1054
#
#
# bestTest = 12.4011581
# bestIteration = 1222
#
#
# bestTest = 16.90838584
# bestIteration = 1272
#
#
# bestTest = 12.10641657
# bestIteration = 821
#
#
# bestTest = 16.68265013
# bestIteration = 1346
#
#
# bestTest = 12.69190662
# bestIteration = 1379
#
#
# bestTest = 12.81049218
# bestIteration = 1387
#
#
# bestTest = 12.36883836
# bestIteration = 1414
#
#
# bestTest = 12.23406307
# bestIteration = 1593
#
#
# bestTest = 12.67884913
# bestIteration = 1619
#
#
# bestTest = 12.3918109
# bestIteration = 1572
#
#
# bestTest = 14.40220354
# bestIteration = 1873
#
#
# bestTest = 12.05464533
# bestIteration = 1838
#
#
# bestTest = 12.299531
# bestIteration = 2074
#
#
# bestTest = 12.28812156
# bestIteration = 2294
#
#
# bestTest = 12.32391419
# bestIteration = 2150
#
#
# bestTest = 14.49736409
# bestIteration = 2357
#
#
# bestTest = 12.31411565
# bestIteration = 2411
#
#
# bestTest = 12.25082632
# bestIteration = 2444
#
#
# bestTest = 14.30014367
# bestIteration = 2497
#
#
# bestTest = 22.11065755
# bestIteration = 144
#
#
# bestTest = 17.66242114
# bestIteration = 443
#
#
# bestTest = 13.85523446
# bestIteration = 572
#
#
# bestTest = 13.32661355
# bestIteration = 626
#
#
# bestTest = 14.80971964
# bestIteration = 957
#
#
# bestTest = 13.7909977
# bestIteration = 1072
#
#
# bestTest = 12.61256802
# bestIteration = 1312
#
#
# bestTest = 13.89690083
# bestIteration = 1458
#
#
# bestTest = 13.79004896
# bestIteration = 1519
#
#
# bestTest = 13.93564837
# bestIteration = 2019
#
#
# bestTest = 12.70281724
# bestIteration = 2126
#
#
# bestTest = 12.47222638
# bestIteration = 1639
#
#
# bestTest = 12.52652961
# bestIteration = 2482
#
#
# bestTest = 16.6057032
# bestIteration = 268
#
#
# bestTest = 25.4302749
# bestIteration = 437
#
#
# bestTest = 17.46456212
# bestIteration = 787
#
#
# bestTest = 13.54359753
# bestIteration = 824
#
#
# bestTest = 20.37548618
# bestIteration = 1002
#
#
# bestTest = 12.51354535
# bestIteration = 1097
#
#
# bestTest = 12.91947609
# bestIteration = 1174
#
#
# bestTest = 12.78875102
# bestIteration = 1535
#
#
# bestTest = 12.78275876
# bestIteration = 1820
#
#
# bestTest = 12.38544797
# bestIteration = 1586
#
#
# bestTest = 15.56459245
# bestIteration = 2305
#
#
# bestTest = 16.78309681
# bestIteration = 199
#
#
# bestTest = 15.69444648
# bestIteration = 298
#
#
# bestTest = 13.21435378
# bestIteration = 395
#
#
# bestTest = 14.35005431
# bestIteration = 431
#
#
# bestTest = 16.51832259
# bestIteration = 500
#
#
# bestTest = 13.39055633
# bestIteration = 929
#
#
# bestTest = 13.07234703
# bestIteration = 938
#
#
# bestTest = 12.85827145
# bestIteration = 1310
#
#
# bestTest = 13.21340006
# bestIteration = 1319
#
#
# bestTest = 13.83856882
# bestIteration = 1381
#
#
# bestTest = 12.85309816
# bestIteration = 1085
#
#
# bestTest = 13.04041183
# bestIteration = 1903
#
#
# bestTest = 12.85309816
# bestIteration = 1085
#
#
# bestTest = 19.2115597
# bestIteration = 82
#
#
# bestTest = 22.28776818
# bestIteration = 126
#
#
# bestTest = 14.11797736
# bestIteration = 438
#
#
# bestTest = 18.2102887
# bestIteration = 474
#
#
# bestTest = 19.00166827
# bestIteration = 1009
#
#
# bestTest = 13.00507405
# bestIteration = 1137
#
#
# bestTest = 13.2917683
# bestIteration = 1100
#
#
# bestTest = 13.9123215
# bestIteration = 1469
#
#
# bestTest = 14.15879297
# bestIteration = 1485
#
#
# bestTest = 16.34622303
# bestIteration = 1802
#
#
# bestTest = 12.75360913
# bestIteration = 2022
#
#
# bestTest = 12.8638034
# bestIteration = 2101
#
#
# bestTest = 13.31311706
# bestIteration = 2157
#
#
# bestTest = 13.00452129
# bestIteration = 2243
#
#
# bestTest = 12.76030511
# bestIteration = 2193
#
#
# bestTest = 14.51592569
# bestIteration = 2348
#
#
# bestTest = 13.31015262
# bestIteration = 1442
#
#
# bestTest = 20.00144509
# bestIteration = 208
#
#
# bestTest = 15.96324641
# bestIteration = 228
#
#
# bestTest = 16.24873998
# bestIteration = 522
#
#
# bestTest = 13.68654215
# bestIteration = 527
#
#
# bestTest = 13.26320285
# bestIteration = 701
#
#
# bestTest = 14.18659901
# bestIteration = 797
#
#
# bestTest = 13.1550932
# bestIteration = 849
#
#
# bestTest = 12.89815107
# bestIteration = 895
#
#
# bestTest = 18.42922785
# bestIteration = 1135
#
#
# bestTest = 13.11430309
# bestIteration = 1177
#
#
# bestTest = 12.94307175
# bestIteration = 1388
#
#
# bestTest = 13.79662234
# bestIteration = 1444
#
#
# bestTest = 13.15954628
# bestIteration = 588
#
#
# bestTest = 12.88169391
# bestIteration = 1837
#
#
# bestTest = 13.18082381
# bestIteration = 1940
#
#
# bestTest = 12.87442121
# bestIteration = 2329
#
#
# bestTest = 16.9434963
# bestIteration = 145
#
#
# bestTest = 18.01437187
# bestIteration = 216
#
#
# bestTest = 16.30355795
# bestIteration = 255
#
#
# bestTest = 13.99664197
# bestIteration = 675
#
#
# bestTest = 14.41725646
# bestIteration = 1074
#
#
# bestTest = 14.96939067
# bestIteration = 1212
#
#
# bestTest = 15.61378682
# bestIteration = 1258
#
#
# bestTest = 13.97650046
# bestIteration = 706
#
#
# bestTest = 13.97650046
# bestIteration = 706
#
#
# bestTest = 15.67713912
# bestIteration = 2306
#
#
# bestTest = 13.35323144
# bestIteration = 2320
#
#
# bestTest = 15.65983475
# bestIteration = 2327
#
#
# bestTest = 25.28196686
# bestIteration = 247
#
#
# bestTest = 22.7536306
# bestIteration = 375
#
#
# bestTest = 14.5777386
# bestIteration = 530
#
#
# bestTest = 13.66576965
# bestIteration = 729
#
#
# bestTest = 16.24820634
# bestIteration = 860
#
#
# bestTest = 13.68173777
# bestIteration = 1053
#
#
# bestTest = 17.04402535
# bestIteration = 1224
#
#
# bestTest = 13.51648237
# bestIteration = 2076
#
#
# bestTest = 15.90087579
# bestIteration = 184
#
#
# bestTest = 23.05639557
# bestIteration = 346
#
#
# bestTest = 13.79028302
# bestIteration = 590
#
#
# bestTest = 19.75253926
# bestIteration = 659
#
#
# bestTest = 14.07670289
# bestIteration = 786
#
#
# bestTest = 13.9309505
# bestIteration = 842
#
#
# bestTest = 14.08747085
# bestIteration = 933
#
#
# bestTest = 13.61363985
# bestIteration = 1126
#
#
# bestTest = 17.74551239
# bestIteration = 1164
#
#
# bestTest = 13.7936821
# bestIteration = 1269
#
#
# bestTest = 16.25407467
# bestIteration = 1347
#
#
# bestTest = 13.51633295
# bestIteration = 2339
#
#
# bestTest = 13.51163972
# bestIteration = 2239
#
#
# bestTest = 25.40654153
# bestIteration = 124
#
#
# bestTest = 19.58455003
# bestIteration = 197
#
#
# bestTest = 15.61825505
# bestIteration = 219
#
#
# bestTest = 27.24652851
# bestIteration = 294
#
#
# bestTest = 19.07156495
# bestIteration = 378
#
#
# bestTest = 17.90249988
# bestIteration = 411
#
#
# bestTest = 14.5969586
# bestIteration = 840
#
#
# bestTest = 21.68119269
# bestIteration = 909
#
#
# bestTest = 11.86498622
# bestIteration = 1000
#
#
# bestTest = 12.99495454
# bestIteration = 1093
#
#
# bestTest = 24.85847584
# bestIteration = 59
#
#
# bestTest = 22.58575668
# bestIteration = 322
#
#
# bestTest = 21.64304401
# bestIteration = 885
#
#
# bestTest = 12.37880918
# bestIteration = 925
#
#
# bestTest = 12.7315049
# bestIteration = 1323
#
#
# bestTest = 12.6695277
# bestIteration = 1413
#
#
# bestTest = 13.07002663
# bestIteration = 1477
#
#
# bestTest = 18.83057213
# bestIteration = 1684
#
#
# bestTest = 14.52971938
# bestIteration = 1934
#
#
# bestTest = 12.30128755
# bestIteration = 1144
#
#
# bestTest = 12.56068652
# bestIteration = 2445
#
#
# bestTest = 28.01407817
# bestIteration = 82
#
#
# bestTest = 16.00411247
# bestIteration = 663
#
#
# bestTest = 13.69232868
# bestIteration = 674
#
#
# bestTest = 15.83717498
# bestIteration = 1278
#
#
# bestTest = 13.13217683
# bestIteration = 1298
#
#
# bestTest = 14.69008547
# bestIteration = 1444
#
#
# bestTest = 13.39159376
# bestIteration = 1590
#
#
# bestTest = 12.21478863
# bestIteration = 1265
#
#
# bestTest = 53.61878404
# bestIteration = 86
#
#
# bestTest = 16.90123102
# bestIteration = 266
#
#
# bestTest = 18.71546964
# bestIteration = 306
#
#
# bestTest = 12.49228484
# bestIteration = 342
#
#
# bestTest = 13.88629379
# bestIteration = 715
#
#
# bestTest = 13.74507534
# bestIteration = 785
#
#
# bestTest = 12.10641657
# bestIteration = 821
#
#
# bestTest = 15.03455258
# bestIteration = 958
#
#
# bestTest = 15.63967167
# bestIteration = 1026
#
#
# bestTest = 13.46726697
# bestIteration = 1364
#
#
# bestTest = 17.51176037
# bestIteration = 1427
#
#
# bestTest = 12.36411823
# bestIteration = 1511
#
#
# bestTest = 12.26245106
# bestIteration = 1662
#
#
# bestTest = 12.18382284
# bestIteration = 1802
#
#
# bestTest = 16.25171063
# bestIteration = 1886
#
#
# bestTest = 12.3918109
# bestIteration = 1572
#
#
# bestTest = 13.29274056
# bestIteration = 2129
#
#
# bestTest = 12.13270543
# bestIteration = 2236
#
#
# bestTest = 12.05464533
# bestIteration = 1838
#
#
# bestTest = 12.81838373
# bestIteration = 2436
#
#
# bestTest = 14.21261963
# bestIteration = 450
#
#
# bestTest = 17.01880404
# bestIteration = 591
#
#
# bestTest = 21.60904067
# bestIteration = 713
#
#
# bestTest = 21.13739438
# bestIteration = 726
#
#
# bestTest = 12.93512642
# bestIteration = 779
#
#
# bestTest = 16.01271732
# bestIteration = 823
#
#
# bestTest = 14.14685121
# bestIteration = 902
#
#
# bestTest = 20.15261591
# bestIteration = 1117
#
#
# bestTest = 12.63702796
# bestIteration = 957
#
#
# bestTest = 12.77381361
# bestIteration = 1368
#
#
# bestTest = 13.6139563
# bestIteration = 1617
#
#
# bestTest = 13.43302636
# bestIteration = 1768
#
#
# bestTest = 16.24098029
# bestIteration = 1884
#
#
# bestTest = 13.12619689
# bestIteration = 1933
#
#
# bestTest = 13.9243522
# bestIteration = 2470
#
#
# bestTest = 22.65205017
# bestIteration = 77
#
#
# bestTest = 31.17458096
# bestIteration = 85
#
#
# bestTest = 23.0258081
# bestIteration = 143
#
#
# bestTest = 18.25664703
# bestIteration = 392
#
#
# bestTest = 14.6826878
# bestIteration = 735
#
#
# bestTest = 13.09172519
# bestIteration = 758
#
#
# bestTest = 12.32608842
# bestIteration = 762
#
#
# bestTest = 13.10788124
# bestIteration = 1058
#
#
# bestTest = 13.41847401
# bestIteration = 1091
#
#
# bestTest = 20.18571978
# bestIteration = 1134
#
#
# bestTest = 13.70587154
# bestIteration = 1164
#
#
# bestTest = 15.77699898
# bestIteration = 1357
#
#
# bestTest = 19.03718971
# bestIteration = 1607
#
#
# bestTest = 18.27828267
# bestIteration = 1669
#
#
# bestTest = 12.62247562
# bestIteration = 1591
#
#
# bestTest = 12.70259896
# bestIteration = 2002
#
#
# bestTest = 12.78460118
# bestIteration = 1984
#
#
# bestTest = 13.31025183
# bestIteration = 2360
#
#
# bestTest = 43.30638743
# bestIteration = 134
#
#
# bestTest = 14.1834474
# bestIteration = 754
#
#
# bestTest = 14.6746835
# bestIteration = 901
#
#
# bestTest = 12.75703805
# bestIteration = 913
#
#
# bestTest = 13.0164317
# bestIteration = 1077
#
#
# bestTest = 16.89565794
# bestIteration = 1295
#
#
# bestTest = 13.25209311
# bestIteration = 1696
#
#
# bestTest = 12.96876708
# bestIteration = 1821
#
#
# bestTest = 13.13325727
# bestIteration = 2048
#
#
# bestTest = 12.81023229
# bestIteration = 2198
#
#
# bestTest = 18.54516099
# bestIteration = 221
#
#
# bestTest = 16.14171916
# bestIteration = 396
#
#
# bestTest = 13.26053015
# bestIteration = 426
#
#
# bestTest = 17.85095346
# bestIteration = 538
#
#
# bestTest = 14.81333052
# bestIteration = 592
#
#
# bestTest = 15.67345554
# bestIteration = 716
#
#
# bestTest = 13.02528983
# bestIteration = 855
#
#
# bestTest = 13.33267808
# bestIteration = 925
#
#
# bestTest = 13.29067268
# bestIteration = 1723
#
#
# bestTest = 13.60233474
# bestIteration = 1861
#
#
# bestTest = 13.02648333
# bestIteration = 2045
#
#
# bestTest = 14.04802128
# bestIteration = 2087
#
#
# bestTest = 13.20729911
# bestIteration = 574
#
#
# bestTest = 18.28339945
# bestIteration = 308
#
#
# bestTest = 19.93787115
# bestIteration = 542
#
#
# bestTest = 13.08779316
# bestIteration = 796
#
#
# bestTest = 16.20178338
# bestIteration = 1030
#
#
# bestTest = 13.13219165
# bestIteration = 1033
#
#
# bestTest = 13.28297416
# bestIteration = 1261
#
#
# bestTest = 13.15954628
# bestIteration = 588
#
#
# bestTest = 12.78294477
# bestIteration = 1574
#
#
# bestTest = 13.15954628
# bestIteration = 588
#
#
# bestTest = 16.04457569
# bestIteration = 70
#
#
# bestTest = 14.83642827
# bestIteration = 299
#
#
# bestTest = 14.43447317
# bestIteration = 313
#
#
# bestTest = 16.34224208
# bestIteration = 367
#
#
# bestTest = 14.0058035
# bestIteration = 485
#
#
# bestTest = 13.62231425
# bestIteration = 513
#
#
# bestTest = 17.69780586
# bestIteration = 565
#
#
# bestTest = 17.170793
# bestIteration = 729
#
#
# bestTest = 16.49649424
# bestIteration = 750
#
#
# bestTest = 13.98937495
# bestIteration = 985
#
#
# bestTest = 13.60280523
# bestIteration = 1475
#
#
# bestTest = 13.88710075
# bestIteration = 1487
#
#
# bestTest = 13.85473454
# bestIteration = 1764
#
#
# bestTest = 13.68756978
# bestIteration = 1441
#
#
# bestTest = 13.42086666
# bestIteration = 1739
#
#
# bestTest = 13.88817004
# bestIteration = 1841
#
#
# bestTest = 13.73381578
# bestIteration = 1839
#
#
# bestTest = 13.78914132
# bestIteration = 1880
#
#
# bestTest = 15.60406336
# bestIteration = 1913
#
#
# bestTest = 13.73381578
# bestIteration = 1839
#
#
# bestTest = 15.03022486
# bestIteration = 2288
#
#
# bestTest = 16.77355953
# bestIteration = 177
#
#
# bestTest = 16.36281386
# bestIteration = 181
#
#
# bestTest = 13.94742363
# bestIteration = 459
#
#
# bestTest = 15.12859942
# bestIteration = 459
#
#
# bestTest = 15.37535406
# bestIteration = 532
#
#
# bestTest = 14.0743647
# bestIteration = 548
#
#
# bestTest = 13.50075279
# bestIteration = 558
#
#
# bestTest = 19.53193046
# bestIteration = 660
#
#
# bestTest = 13.80318774
# bestIteration = 676
#
#
# bestTest = 17.37311015
# bestIteration = 815
#
#
# bestTest = 13.53052323
# bestIteration = 1261
#
#
# bestTest = 17.48820981
# bestIteration = 1289
#
#
# bestTest = 13.64591363
# bestIteration = 1383
#
#
# bestTest = 13.6436314
# bestIteration = 1520
#
#
# bestTest = 13.74792482
# bestIteration = 1506
#
#
# bestTest = 13.66426727
# bestIteration = 1590
#
#
# bestTest = 13.45136882
# bestIteration = 1949
#
#
# bestTest = 13.74792482
# bestIteration = 1506
#
#
# bestTest = 13.56202145
# bestIteration = 1501
#
#
# bestTest = 23.5298727
# bestIteration = 368
#
#
# bestTest = 17.7207226
# bestIteration = 729
#
#
# bestTest = 13.91467455
# bestIteration = 874
#
#
# bestTest = 14.82859976
# bestIteration = 964
#
#
# bestTest = 13.62628196
# bestIteration = 1056
#
#
# bestTest = 13.58885283
# bestIteration = 1083
#
#
# bestTest = 17.79128224
# bestIteration = 1145
#
#
# bestTest = 13.77239554
# bestIteration = 1526
#
#
# bestTest = 13.53941357
# bestIteration = 1577
#
#
# bestTest = 13.51375421
# bestIteration = 1913
#
#
# bestTest = 13.50220218
# bestIteration = 1955
#
#
# bestTest = 13.53941357
# bestIteration = 1577
#
#
# bestTest = 13.24914747
# bestIteration = 2263
#
#
# bestTest = 15.27960472
# bestIteration = 446
#
#
# bestTest = 22.97767176
# bestIteration = 468
#
#
# bestTest = 12.81179233
# bestIteration = 691
#
#
# bestTest = 12.30094627
# bestIteration = 743
#
#
# bestTest = 20.66882712
# bestIteration = 885
#
#
# bestTest = 13.65698837
# bestIteration = 1123
#
#
# bestTest = 20.87059261
# bestIteration = 1190
#
#
# bestTest = 12.71309028
# bestIteration = 1359
#
#
# bestTest = 19.59165116
# bestIteration = 1475
#
#
# bestTest = 12.05900118
# bestIteration = 1720
#
#
# bestTest = 13.11129791
# bestIteration = 1740
#
#
# bestTest = 16.69290665
# bestIteration = 1985
#
#
# bestTest = 11.89352479
# bestIteration = 1884
#
#
# bestTest = 12.24849244
# bestIteration = 2028
#
#
# bestTest = 12.53785862
# bestIteration = 2450
#
#
# bestTest = 11.89352479
# bestIteration = 1884
#
#
# bestTest = 23.7724183
# bestIteration = 246
#
#
# bestTest = 28.78490108
# bestIteration = 349
#
#
# bestTest = 22.71739744
# bestIteration = 362
#
#
# bestTest = 14.23162877
# bestIteration = 403
#
#
# bestTest = 18.15873342
# bestIteration = 428
#
#
# bestTest = 17.88468058
# bestIteration = 583
#
#
# bestTest = 15.4366628
# bestIteration = 677
#
#
# bestTest = 14.62914087
# bestIteration = 1019
#
#
# bestTest = 15.95840981
# bestIteration = 1111
#
#
# bestTest = 15.85983322
# bestIteration = 1350
#
#
# bestTest = 12.24425967
# bestIteration = 1977
#
#
# bestTest = 12.30128755
# bestIteration = 1144
#
#
# bestTest = 43.15084929
# bestIteration = 140
#
#
# bestTest = 24.30127926
# bestIteration = 259
#
#
# bestTest = 19.99313974
# bestIteration = 519
#
#
# bestTest = 20.81472646
# bestIteration = 581
#
#
# bestTest = 15.99605597
# bestIteration = 664
#
#
# bestTest = 12.8680641
# bestIteration = 881
#
#
# bestTest = 14.53785768
# bestIteration = 961
#
#
# bestTest = 21.9395516
# bestIteration = 1073
#
#
# bestTest = 14.52846622
# bestIteration = 1082
#
#
# bestTest = 12.5946006
# bestIteration = 1410
#
#
# bestTest = 12.55589044
# bestIteration = 1418
#
#
# bestTest = 14.87262112
# bestIteration = 1843
#
#
# bestTest = 19.86624338
# bestIteration = 2002
#
#
# bestTest = 14.15633629
# bestIteration = 2290
#
#
# bestTest = 16.75335843
# bestIteration = 199
#
#
# bestTest = 12.22312786
# bestIteration = 948
#
#
# bestTest = 19.34527651
# bestIteration = 1090
#
#
# bestTest = 14.19234854
# bestIteration = 1186
#
#
# bestTest = 16.954096
# bestIteration = 1257
#
#
# bestTest = 12.49477495
# bestIteration = 1886
#
#
# bestTest = 13.82450555
# bestIteration = 2255
#
#
# bestTest = 13.76769394
# bestIteration = 2320
#
#
# bestTest = 25.38913026
# bestIteration = 326
#
#
# bestTest = 15.11419805
# bestIteration = 397
#
#
# bestTest = 12.91556354
# bestIteration = 565
#
#
# bestTest = 21.17649381
# bestIteration = 630
#
#
# bestTest = 20.94261979
# bestIteration = 752
#
#
# bestTest = 14.2039044
# bestIteration = 887
#
#
# bestTest = 12.90306334
# bestIteration = 940
#
#
# bestTest = 12.67036302
# bestIteration = 960
#
#
# bestTest = 13.33939986
# bestIteration = 1096
#
#
# bestTest = 14.01309468
# bestIteration = 1621
#
#
# bestTest = 12.87075898
# bestIteration = 1256
#
#
# bestTest = 17.7289793
# bestIteration = 127
#
#
# bestTest = 18.09219547
# bestIteration = 206
#
#
# bestTest = 14.34574509
# bestIteration = 222
#
#
# bestTest = 18.00357783
# bestIteration = 319
#
#
# bestTest = 14.32590409
# bestIteration = 411
#
#
# bestTest = 19.7519642
# bestIteration = 417
#
#
# bestTest = 17.02852391
# bestIteration = 587
#
#
# bestTest = 23.38274095
# bestIteration = 595
#
#
# bestTest = 14.22412299
# bestIteration = 796
#
#
# bestTest = 12.70559292
# bestIteration = 866
#
#
# bestTest = 20.14111951
# bestIteration = 989
#
#
# bestTest = 12.9523656
# bestIteration = 1091
#
#
# bestTest = 18.93144927
# bestIteration = 1177
#
#
# bestTest = 14.22536768
# bestIteration = 1267
#
#
# bestTest = 19.34939527
# bestIteration = 1330
#
#
# bestTest = 13.51915791
# bestIteration = 1418
#
#
# bestTest = 12.70559292
# bestIteration = 866
#
#
# bestTest = 13.13178649
# bestIteration = 1729
#
#
# bestTest = 12.71685493
# bestIteration = 1786
#
#
# bestTest = 12.48212746
# bestIteration = 2057
#
#
# bestTest = 12.461106
# bestIteration = 2230
#
#
# bestTest = 12.72630724
# bestIteration = 2332
#
#
# bestTest = 13.33002443
# bestIteration = 2466
#
#
# bestTest = 21.57849081
# bestIteration = 64
#
#
# bestTest = 28.53435385
# bestIteration = 244
#
#
# bestTest = 13.67311811
# bestIteration = 347
#
#
# bestTest = 17.91583319
# bestIteration = 360
#
#
# bestTest = 13.11927913
# bestIteration = 450
#
#
# bestTest = 16.57144174
# bestIteration = 476
#
#
# bestTest = 15.19953677
# bestIteration = 1221
#
#
# bestTest = 12.72868035
# bestIteration = 1166
#
#
# bestTest = 13.21601552
# bestIteration = 1363
#
#
# bestTest = 13.09404138
# bestIteration = 640
#
#
# bestTest = 12.9837606
# bestIteration = 1663
#
#
# bestTest = 13.05333682
# bestIteration = 1951
#
#
# bestTest = 13.03884541
# bestIteration = 2061
#
#
# bestTest = 13.39266815
# bestIteration = 2066
#
#
# bestTest = 12.9959799
# bestIteration = 2362
#
#
# bestTest = 12.96531296
# bestIteration = 2214
#
#
# bestTest = 12.86749725
# bestIteration = 2431
#
#
# bestTest = 13.57897031
# bestIteration = 362
#
#
# bestTest = 14.82682011
# bestIteration = 437
#
#
# bestTest = 20.57120397
# bestIteration = 441
#
#
# bestTest = 19.99628351
# bestIteration = 763
#
#
# bestTest = 18.2338204
# bestIteration = 802
#
#
# bestTest = 13.02528983
# bestIteration = 855
#
#
# bestTest = 19.59930786
# bestIteration = 859
#
#
# bestTest = 13.34835662
# bestIteration = 1038
#
#
# bestTest = 13.2873858
# bestIteration = 1327
#
#
# bestTest = 12.99277167
# bestIteration = 1627
#
#
# bestTest = 13.07193095
# bestIteration = 1853
#
#
# bestTest = 12.65645949
# bestIteration = 2256
#
#
# bestTest = 12.98848669
# bestIteration = 2275
#
#
# bestTest = 13.2917683
# bestIteration = 1100
#
#
# bestTest = 13.21601086
# bestIteration = 1064
#
#
# bestTest = 72.68951627
# bestIteration = 49
#
#
# bestTest = 28.68041375
# bestIteration = 71
#
#
# bestTest = 13.37389421
# bestIteration = 446
#
#
# bestTest = 13.69914431
# bestIteration = 531
#
#
# bestTest = 19.38702464
# bestIteration = 715
#
#
# bestTest = 13.15688666
# bestIteration = 1017
#
#
# bestTest = 18.53704155
# bestIteration = 1088
#
#
# bestTest = 13.03871249
# bestIteration = 1247
#
#
# bestTest = 12.97439827
# bestIteration = 1746
#
#
# bestTest = 16.11361923
# bestIteration = 2089
#
#
# bestTest = 12.95824178
# bestIteration = 2307
#
#
# bestTest = 12.75382461
# bestIteration = 1539
#
#
# bestTest = 13.22826492
# bestIteration = 2418
#
#
# bestTest = 64.91182588
# bestIteration = 70
#
#
# bestTest = 38.59278062
# bestIteration = 172
#
#
# bestTest = 16.63566853
# bestIteration = 363
#
#
# bestTest = 14.18959439
# bestIteration = 762
#
#
# bestTest = 17.50986546
# bestIteration = 824
#
#
# bestTest = 16.23740036
# bestIteration = 985
#
#
# bestTest = 15.74742663
# bestIteration = 1203
#
#
# bestTest = 13.81815901
# bestIteration = 1629
#
#
# bestTest = 13.40928615
# bestIteration = 1599
#
#
# bestTest = 13.8094309
# bestIteration = 1682
#
#
# bestTest = 13.42086666
# bestIteration = 1739
#
#
# bestTest = 13.39793868
# bestIteration = 2061
#
#
# bestTest = 13.39569223
# bestIteration = 2430
#
#
# bestTest = 14.02246663
# bestIteration = 432
#
#
# bestTest = 14.11797547
# bestIteration = 580
#
#
# bestTest = 18.61166974
# bestIteration = 793
#
#
# bestTest = 17.23994494
# bestIteration = 1133
#
#
# bestTest = 13.66426727
# bestIteration = 1590
#
#
# bestTest = 15.19556641
# bestIteration = 2140
#
#
# bestTest = 19.96482162
# bestIteration = 50
#
#
# bestTest = 66.38496377
# bestIteration = 67
#
#
# bestTest = 18.53600895
# bestIteration = 209
#
#
# bestTest = 14.96632434
# bestIteration = 261
#
#
# bestTest = 14.70369004
# bestIteration = 738
#
#
# bestTest = 13.48440465
# bestIteration = 1227
#
#
# bestTest = 17.73570746
# bestIteration = 1352
#
#
# bestTest = 16.10818509
# bestIteration = 1393
#
#
# bestTest = 13.47934678
# bestIteration = 1371
#
#
# bestTest = 13.65287947
# bestIteration = 1585
#
#
# bestTest = 13.34329936
# bestIteration = 1657
#
#
# bestTest = 17.06290653
# bestIteration = 1742
#
#
# bestTest = 13.24389921
# bestIteration = 1875
#
#
# bestTest = 14.10217533
# bestIteration = 1601
#
#
# bestTest = 13.5642378
# bestIteration = 2135
#
#
# bestTest = 16.30447655
# bestIteration = 2151
#
#
# bestTest = 13.61363985
# bestIteration = 1126
#
#
# bestTest = 16.05541407
# bestIteration = 2302
#
#
# bestTest = 13.30146156
# bestIteration = 2401
#
#
# bestTest = 13.90172887
# bestIteration = 2430
#
# Training on fold [0/5]
#
# bestTest = 20.58700303
# bestIteration = 956
#
# Training on fold [1/5]
#
# bestTest = 13.72688065
# bestIteration = 994
#
# Training on fold [2/5]
#
# bestTest = 16.81162632
# bestIteration = 1000
#
# Training on fold [3/5]
#
# bestTest = 13.35469039
# bestIteration = 952
#
# Training on fold [4/5]
#
# bestTest = 12.1530829
# bestIteration = 996
#
#   Best Catboost: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 4, 'learning_rate': 0.1, 'l2_leaf_reg': 3, 'iterations': 1001}
# Extra Trees: CV Training RMSE = 13.023, R²=0.903 | Testing RMSE=24.124, R²=0.815
# Bagging Regressor: CV Training RMSE = 13.693, R²=0.892 | Testing RMSE=26.333, R²=0.780
# ...
#
#
# bestTest = 24.33230802
# bestIteration = 124
#
#
# bestTest = 19.17050395
# bestIteration = 197
#
#
# bestTest = 15.68220861
# bestIteration = 219
#
#
# bestTest = 26.25369815
# bestIteration = 294
#
#
# bestTest = 18.15203319
# bestIteration = 379
#
#
# bestTest = 17.59793461
# bestIteration = 411
#
#
# bestTest = 14.35218416
# bestIteration = 845
#
#
# bestTest = 21.35344673
# bestIteration = 909
#
#
# bestTest = 11.93573022
# bestIteration = 983
#
#
# bestTest = 12.63108955
# bestIteration = 1087
#
#
# bestTest = 25.23100288
# bestIteration = 59
#
#
# bestTest = 22.05519936
# bestIteration = 322
#
#
# bestTest = 21.73504833
# bestIteration = 885
#
#
# bestTest = 11.99805246
# bestIteration = 929
#
#
# bestTest = 12.06785658
# bestIteration = 1324
#
#
# bestTest = 12.00162184
# bestIteration = 1367
#
#
# bestTest = 12.19048469
# bestIteration = 1477
#
#
# bestTest = 18.16461814
# bestIteration = 1684
#
#
# bestTest = 13.78705887
# bestIteration = 1937
#
#
# bestTest = 11.76610899
# bestIteration = 1963
#
#
# bestTest = 12.03552452
# bestIteration = 2439
#
#
# bestTest = 27.42009745
# bestIteration = 82
#
#
# bestTest = 15.4790705
# bestIteration = 663
#
#
# bestTest = 13.54863485
# bestIteration = 674
#
#
# bestTest = 15.23025742
# bestIteration = 1280
#
#
# bestTest = 12.49860172
# bestIteration = 1295
#
#
# bestTest = 14.13073539
# bestIteration = 1444
#
#
# bestTest = 12.8586228
# bestIteration = 1590
#
#
# bestTest = 11.88124452
# bestIteration = 1904
#
#
# bestTest = 52.06941336
# bestIteration = 86
#
#
# bestTest = 16.00109293
# bestIteration = 266
#
#
# bestTest = 18.55362162
# bestIteration = 307
#
#
# bestTest = 12.12926812
# bestIteration = 341
#
#
# bestTest = 12.72733619
# bestIteration = 716
#
#
# bestTest = 13.00803392
# bestIteration = 785
#
#
# bestTest = 11.94069041
# bestIteration = 763
#
#
# bestTest = 14.52384087
# bestIteration = 958
#
#
# bestTest = 15.22856119
# bestIteration = 1026
#
#
# bestTest = 12.71961428
# bestIteration = 1364
#
#
# bestTest = 16.39322785
# bestIteration = 1427
#
#
# bestTest = 11.63134555
# bestIteration = 1598
#
#
# bestTest = 11.81899436
# bestIteration = 1669
#
#
# bestTest = 11.60035914
# bestIteration = 1822
#
#
# bestTest = 15.20955707
# bestIteration = 1886
#
#
# bestTest = 11.84703161
# bestIteration = 1960
#
#
# bestTest = 12.81734474
# bestIteration = 2132
#
#
# bestTest = 11.5681934
# bestIteration = 2005
#
#
# bestTest = 11.69431289
# bestIteration = 1201
#
#
# bestTest = 12.12561593
# bestIteration = 2436
#
#
# bestTest = 12.52602949
# bestIteration = 450
#
#
# bestTest = 16.29285632
# bestIteration = 590
#
#
# bestTest = 21.22895324
# bestIteration = 713
#
#
# bestTest = 20.68441468
# bestIteration = 726
#
#
# bestTest = 12.02409684
# bestIteration = 776
#
#
# bestTest = 15.5736491
# bestIteration = 822
#
#
# bestTest = 13.30865196
# bestIteration = 902
#
#
# bestTest = 19.35756171
# bestIteration = 1115
#
#
# bestTest = 11.91404258
# bestIteration = 1366
#
#
# bestTest = 11.65658543
# bestIteration = 1350
#
#
# bestTest = 12.8171967
# bestIteration = 1618
#
#
# bestTest = 12.62946455
# bestIteration = 1767
#
#
# bestTest = 15.4581063
# bestIteration = 1884
#
#
# bestTest = 12.37841814
# bestIteration = 1933
#
#
# bestTest = 13.29404846
# bestIteration = 2470
#
#
# bestTest = 21.70573016
# bestIteration = 77
#
#
# bestTest = 30.20290924
# bestIteration = 85
#
#
# bestTest = 22.5764347
# bestIteration = 143
#
#
# bestTest = 17.77248746
# bestIteration = 392
#
#
# bestTest = 14.1264021
# bestIteration = 736
#
#
# bestTest = 12.03886139
# bestIteration = 759
#
#
# bestTest = 11.79100308
# bestIteration = 867
#
#
# bestTest = 12.30161662
# bestIteration = 1058
#
#
# bestTest = 12.57496841
# bestIteration = 1091
#
#
# bestTest = 19.86748245
# bestIteration = 1134
#
#
# bestTest = 12.67988376
# bestIteration = 1166
#
#
# bestTest = 15.56569882
# bestIteration = 1356
#
#
# bestTest = 18.42658661
# bestIteration = 1607
#
#
# bestTest = 17.28644738
# bestIteration = 1669
#
#
# bestTest = 11.8115554
# bestIteration = 1700
#
#
# bestTest = 12.01708641
# bestIteration = 2003
#
#
# bestTest = 11.71416574
# bestIteration = 1978
#
#
# bestTest = 12.34323562
# bestIteration = 2362
#
#
# bestTest = 41.73194735
# bestIteration = 134
#
#
# bestTest = 13.2552002
# bestIteration = 755
#
#
# bestTest = 13.2623319
# bestIteration = 901
#
#
# bestTest = 11.9285159
# bestIteration = 896
#
#
# bestTest = 11.90408064
# bestIteration = 1100
#
#
# bestTest = 15.73508652
# bestIteration = 1295
#
#
# bestTest = 12.14621707
# bestIteration = 1693
#
#
# bestTest = 12.17014846
# bestIteration = 1875
#
#
# bestTest = 12.10827327
# bestIteration = 2049
#
#
# bestTest = 11.85479613
# bestIteration = 2203
#
#
# bestTest = 17.25702516
# bestIteration = 221
#
#
# bestTest = 15.09345815
# bestIteration = 396
#
#
# bestTest = 12.12447151
# bestIteration = 422
#
#
# bestTest = 16.30132343
# bestIteration = 538
#
#
# bestTest = 13.53358876
# bestIteration = 592
#
#
# bestTest = 14.78048269
# bestIteration = 716
#
#
# bestTest = 12.21782251
# bestIteration = 853
#
#
# bestTest = 12.67347275
# bestIteration = 925
#
#
# bestTest = 12.33333167
# bestIteration = 1724
#
#
# bestTest = 12.94176231
# bestIteration = 1861
#
#
# bestTest = 11.86908307
# bestIteration = 2050
#
#
# bestTest = 13.15357256
# bestIteration = 2087
#
#
# bestTest = 11.91280017
# bestIteration = 2114
#
#
# bestTest = 17.25042519
# bestIteration = 307
#
#
# bestTest = 19.34692422
# bestIteration = 542
#
#
# bestTest = 12.17914743
# bestIteration = 811
#
#
# bestTest = 15.50953483
# bestIteration = 1030
#
#
# bestTest = 12.06495588
# bestIteration = 1032
#
#
# bestTest = 12.30696121
# bestIteration = 1264
#
#
# bestTest = 12.34582554
# bestIteration = 1005
#
#
# bestTest = 12.03447704
# bestIteration = 1571
#
#
# bestTest = 12.34582554
# bestIteration = 1005
#
#
# bestTest = 14.6674919
# bestIteration = 71
#
#
# bestTest = 13.45333423
# bestIteration = 297
#
#
# bestTest = 12.79470461
# bestIteration = 313
#
#
# bestTest = 14.7633939
# bestIteration = 366
#
#
# bestTest = 12.87929997
# bestIteration = 473
#
#
# bestTest = 12.4333377
# bestIteration = 516
#
#
# bestTest = 16.20726156
# bestIteration = 565
#
#
# bestTest = 15.94562458
# bestIteration = 729
#
#
# bestTest = 15.12434624
# bestIteration = 750
#
#
# bestTest = 12.24594286
# bestIteration = 988
#
#
# bestTest = 12.19907208
# bestIteration = 1470
#
#
# bestTest = 12.65814581
# bestIteration = 1488
#
#
# bestTest = 12.26967572
# bestIteration = 1722
#
#
# bestTest = 12.55219079
# bestIteration = 1451
#
#
# bestTest = 12.09098277
# bestIteration = 1675
#
#
# bestTest = 12.72573183
# bestIteration = 1842
#
#
# bestTest = 12.2535289
# bestIteration = 1810
#
#
# bestTest = 12.46660898
# bestIteration = 1880
#
#
# bestTest = 14.24887499
# bestIteration = 1914
#
#
# bestTest = 12.25027309
# bestIteration = 1967
#
#
# bestTest = 13.73508667
# bestIteration = 2288
#
#
# bestTest = 15.26849774
# bestIteration = 177
#
#
# bestTest = 15.15186925
# bestIteration = 181
#
#
# bestTest = 12.90213952
# bestIteration = 450
#
#
# bestTest = 14.09723124
# bestIteration = 460
#
#
# bestTest = 14.40137006
# bestIteration = 532
#
#
# bestTest = 12.65840158
# bestIteration = 549
#
#
# bestTest = 12.57643526
# bestIteration = 564
#
#
# bestTest = 18.48349188
# bestIteration = 660
#
#
# bestTest = 12.51353425
# bestIteration = 676
#
#
# bestTest = 16.17754549
# bestIteration = 815
#
#
# bestTest = 12.66809441
# bestIteration = 1215
#
#
# bestTest = 17.11715096
# bestIteration = 1289
#
#
# bestTest = 12.51924206
# bestIteration = 1382
#
#
# bestTest = 12.55924468
# bestIteration = 1525
#
#
# bestTest = 12.24244817
# bestIteration = 1672
#
#
# bestTest = 12.20889502
# bestIteration = 1943
#
#
# bestTest = 12.26884476
# bestIteration = 1966
#
#
# bestTest = 12.24244817
# bestIteration = 1672
#
#
# bestTest = 12.35432567
# bestIteration = 2114
#
#
# bestTest = 22.42987107
# bestIteration = 368
#
#
# bestTest = 16.6498639
# bestIteration = 729
#
#
# bestTest = 12.61609478
# bestIteration = 869
#
#
# bestTest = 13.95527815
# bestIteration = 964
#
#
# bestTest = 12.83890748
# bestIteration = 1047
#
#
# bestTest = 12.37232327
# bestIteration = 1089
#
#
# bestTest = 16.86044768
# bestIteration = 1142
#
#
# bestTest = 12.43372746
# bestIteration = 1773
#
#
# bestTest = 12.34868398
# bestIteration = 1789
#
#
# bestTest = 12.54347021
# bestIteration = 1915
#
#
# bestTest = 12.44427812
# bestIteration = 1915
#
#
# bestTest = 12.34626666
# bestIteration = 1970
#
#
# bestTest = 12.5638004
# bestIteration = 2255
#
#
# bestTest = 14.67837721
# bestIteration = 446
#
#
# bestTest = 22.49341793
# bestIteration = 468
#
#
# bestTest = 12.62342351
# bestIteration = 682
#
#
# bestTest = 12.19340767
# bestIteration = 742
#
#
# bestTest = 20.21290684
# bestIteration = 885
#
#
# bestTest = 13.16044727
# bestIteration = 1123
#
#
# bestTest = 20.36979312
# bestIteration = 1190
#
#
# bestTest = 12.38267479
# bestIteration = 1362
#
#
# bestTest = 18.23492774
# bestIteration = 1475
#
#
# bestTest = 12.04713866
# bestIteration = 1739
#
#
# bestTest = 12.68888617
# bestIteration = 1737
#
#
# bestTest = 16.0110425
# bestIteration = 1985
#
#
# bestTest = 11.87047863
# bestIteration = 1959
#
#
# bestTest = 11.8909902
# bestIteration = 2187
#
#
# bestTest = 12.34447961
# bestIteration = 2443
#
#
# bestTest = 11.82357978
# bestIteration = 2453
#
#
# bestTest = 23.11230656
# bestIteration = 246
#
#
# bestTest = 28.02994253
# bestIteration = 349
#
#
# bestTest = 22.48868411
# bestIteration = 362
#
#
# bestTest = 13.80480112
# bestIteration = 403
#
#
# bestTest = 17.44614214
# bestIteration = 429
#
#
# bestTest = 17.07014594
# bestIteration = 582
#
#
# bestTest = 15.1135142
# bestIteration = 676
#
#
# bestTest = 13.72900213
# bestIteration = 1020
#
#
# bestTest = 14.98072435
# bestIteration = 1114
#
#
# bestTest = 15.29960208
# bestIteration = 1350
#
#
# bestTest = 11.8005081
# bestIteration = 1978
#
#
# bestTest = 11.76610899
# bestIteration = 1963
#
#
# bestTest = 42.11502558
# bestIteration = 140
#
#
# bestTest = 23.98073069
# bestIteration = 259
#
#
# bestTest = 19.33016663
# bestIteration = 519
#
#
# bestTest = 20.96863626
# bestIteration = 581
#
#
# bestTest = 15.46994828
# bestIteration = 664
#
#
# bestTest = 12.17655745
# bestIteration = 884
#
#
# bestTest = 13.8200133
# bestIteration = 961
#
#
# bestTest = 21.59831902
# bestIteration = 1073
#
#
# bestTest = 13.89271721
# bestIteration = 1081
#
#
# bestTest = 12.25339047
# bestIteration = 1410
#
#
# bestTest = 12.53656111
# bestIteration = 1418
#
#
# bestTest = 14.00846511
# bestIteration = 1842
#
#
# bestTest = 19.00137687
# bestIteration = 2002
#
#
# bestTest = 13.14711364
# bestIteration = 2290
#
#
# bestTest = 15.10663623
# bestIteration = 199
#
#
# bestTest = 11.7714383
# bestIteration = 893
#
#
# bestTest = 18.37264816
# bestIteration = 1090
#
#
# bestTest = 13.68137434
# bestIteration = 1188
#
#
# bestTest = 16.13445351
# bestIteration = 1257
#
#
# bestTest = 11.94869634
# bestIteration = 1882
#
#
# bestTest = 13.1664705
# bestIteration = 2255
#
#
# bestTest = 13.08629962
# bestIteration = 2320
#
#
# bestTest = 24.46093117
# bestIteration = 326
#
#
# bestTest = 14.58875637
# bestIteration = 397
#
#
# bestTest = 12.10317242
# bestIteration = 563
#
#
# bestTest = 20.79409714
# bestIteration = 630
#
#
# bestTest = 20.47477575
# bestIteration = 752
#
#
# bestTest = 13.340638
# bestIteration = 888
#
#
# bestTest = 12.10337223
# bestIteration = 938
#
#
# bestTest = 12.36186675
# bestIteration = 961
#
#
# bestTest = 12.4388752
# bestIteration = 1098
#
#
# bestTest = 13.26508345
# bestIteration = 1621
#
#
# bestTest = 12.13957828
# bestIteration = 387
#
#
# bestTest = 17.35438618
# bestIteration = 127
#
#
# bestTest = 16.64236491
# bestIteration = 206
#
#
# bestTest = 13.07442032
# bestIteration = 220
#
#
# bestTest = 16.82953706
# bestIteration = 319
#
#
# bestTest = 13.05581596
# bestIteration = 410
#
#
# bestTest = 19.1942522
# bestIteration = 417
#
#
# bestTest = 16.29176447
# bestIteration = 585
#
#
# bestTest = 23.26230593
# bestIteration = 595
#
#
# bestTest = 13.37002235
# bestIteration = 793
#
#
# bestTest = 11.88058896
# bestIteration = 802
#
#
# bestTest = 19.7918348
# bestIteration = 990
#
#
# bestTest = 11.97374737
# bestIteration = 1076
#
#
# bestTest = 18.63588092
# bestIteration = 1177
#
#
# bestTest = 13.45046429
# bestIteration = 1265
#
#
# bestTest = 18.82527711
# bestIteration = 1330
#
#
# bestTest = 12.63962253
# bestIteration = 1418
#
#
# bestTest = 11.88058896
# bestIteration = 802
#
#
# bestTest = 12.261118
# bestIteration = 1727
#
#
# bestTest = 11.99490622
# bestIteration = 1780
#
#
# bestTest = 12.07941088
# bestIteration = 2072
#
#
# bestTest = 12.05148497
# bestIteration = 2267
#
#
# bestTest = 11.94919637
# bestIteration = 2331
#
#
# bestTest = 12.9719941
# bestIteration = 2465
#
#
# bestTest = 20.34527047
# bestIteration = 64
#
#
# bestTest = 27.22383803
# bestIteration = 244
#
#
# bestTest = 12.42385154
# bestIteration = 348
#
#
# bestTest = 17.10309247
# bestIteration = 360
#
#
# bestTest = 12.19294575
# bestIteration = 458
#
#
# bestTest = 14.93117559
# bestIteration = 478
#
#
# bestTest = 14.17860521
# bestIteration = 1222
#
#
# bestTest = 11.89194748
# bestIteration = 1245
#
#
# bestTest = 11.90855371
# bestIteration = 1373
#
#
# bestTest = 12.15797944
# bestIteration = 583
#
#
# bestTest = 11.75801694
# bestIteration = 1862
#
#
# bestTest = 11.70924199
# bestIteration = 1950
#
#
# bestTest = 11.69876601
# bestIteration = 2054
#
#
# bestTest = 12.36739995
# bestIteration = 2060
#
#
# bestTest = 11.99123493
# bestIteration = 2361
#
#
# bestTest = 12.14187586
# bestIteration = 2252
#
#
# bestTest = 11.91472047
# bestIteration = 2429
#
#
# bestTest = 12.39933452
# bestIteration = 365
#
#
# bestTest = 13.98254137
# bestIteration = 439
#
#
# bestTest = 19.79912799
# bestIteration = 441
#
#
# bestTest = 19.10055631
# bestIteration = 763
#
#
# bestTest = 17.24864521
# bestIteration = 802
#
#
# bestTest = 12.21782251
# bestIteration = 853
#
#
# bestTest = 18.60412469
# bestIteration = 859
#
#
# bestTest = 12.06704298
# bestIteration = 1093
#
#
# bestTest = 12.00200951
# bestIteration = 1376
#
#
# bestTest = 11.97819919
# bestIteration = 1626
#
#
# bestTest = 11.92691869
# bestIteration = 1860
#
#
# bestTest = 12.07813093
# bestIteration = 2266
#
#
# bestTest = 11.8146806
# bestIteration = 2273
#
#
# bestTest = 12.11883174
# bestIteration = 583
#
#
# bestTest = 12.15336521
# bestIteration = 2010
#
#
# bestTest = 71.34712711
# bestIteration = 49
#
#
# bestTest = 28.33117077
# bestIteration = 71
#
#
# bestTest = 12.26573644
# bestIteration = 416
#
#
# bestTest = 13.08118615
# bestIteration = 531
#
#
# bestTest = 18.58458822
# bestIteration = 715
#
#
# bestTest = 12.07598273
# bestIteration = 1017
#
#
# bestTest = 17.73831132
# bestIteration = 1088
#
#
# bestTest = 12.09674365
# bestIteration = 1286
#
#
# bestTest = 12.10239219
# bestIteration = 1725
#
#
# bestTest = 15.11900142
# bestIteration = 2089
#
#
# bestTest = 12.17838196
# bestIteration = 2306
#
#
# bestTest = 11.935077
# bestIteration = 1228
#
#
# bestTest = 12.69289389
# bestIteration = 2421
#
#
# bestTest = 63.55262096
# bestIteration = 70
#
#
# bestTest = 36.84208044
# bestIteration = 172
#
#
# bestTest = 15.78176069
# bestIteration = 363
#
#
# bestTest = 12.36430358
# bestIteration = 763
#
#
# bestTest = 16.2147841
# bestIteration = 824
#
#
# bestTest = 15.09714475
# bestIteration = 985
#
#
# bestTest = 14.59067441
# bestIteration = 1201
#
#
# bestTest = 12.09205591
# bestIteration = 1626
#
#
# bestTest = 12.45051703
# bestIteration = 1634
#
#
# bestTest = 12.08126097
# bestIteration = 1685
#
#
# bestTest = 12.09098277
# bestIteration = 1675
#
#
# bestTest = 12.42434606
# bestIteration = 2256
#
#
# bestTest = 12.41766577
# bestIteration = 2420
#
#
# bestTest = 12.55780036
# bestIteration = 433
#
#
# bestTest = 12.91892059
# bestIteration = 577
#
#
# bestTest = 17.61636192
# bestIteration = 793
#
#
# bestTest = 16.58671067
# bestIteration = 1133
#
#
# bestTest = 12.21248803
# bestIteration = 1621
#
#
# bestTest = 14.51071447
# bestIteration = 2140
#
#
# bestTest = 18.2077217
# bestIteration = 50
#
#
# bestTest = 64.83401473
# bestIteration = 67
#
#
# bestTest = 17.33970288
# bestIteration = 209
#
#
# bestTest = 13.89688215
# bestIteration = 260
#
#
# bestTest = 13.43356391
# bestIteration = 736
#
#
# bestTest = 12.70217303
# bestIteration = 1289
#
#
# bestTest = 17.09404177
# bestIteration = 1352
#
#
# bestTest = 15.46305176
# bestIteration = 1392
#
#
# bestTest = 12.69293538
# bestIteration = 1424
#
#
# bestTest = 12.62560279
# bestIteration = 1586
#
#
# bestTest = 12.6606228
# bestIteration = 1659
#
#
# bestTest = 16.1811495
# bestIteration = 1742
#
#
# bestTest = 12.30534679
# bestIteration = 1832
#
#
# bestTest = 13.18115353
# bestIteration = 1890
#
#
# bestTest = 12.52409786
# bestIteration = 2131
#
#
# bestTest = 15.55113828
# bestIteration = 2151
#
#
# bestTest = 12.93056905
# bestIteration = 2264
#
#
# bestTest = 15.23268136
# bestIteration = 2302
#
#
# bestTest = 12.32575011
# bestIteration = 2400
#
#
# bestTest = 12.81096679
# bestIteration = 2432
#
# Training on fold [0/5]
#
# bestTest = 17.82094923
# bestIteration = 2191
#
# Training on fold [1/5]
#
# bestTest = 13.19780773
# bestIteration = 2247
#
# Training on fold [2/5]
#
# bestTest = 14.5962013
# bestIteration = 1185
#
# Training on fold [3/5]
#
# bestTest = 13.39879905
# bestIteration = 2250
#
# Training on fold [4/5]
#
# bestTest = 11.85376403
# bestIteration = 2214
#
#   Best Catboost: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.03, 'l2_leaf_reg': 1, 'iterations': 2251}
# Extra Trees: CV Training RMSE = 13.086, R²=0.902 | Testing RMSE=24.610, R²=0.808
# Bagging Regressor: CV Training RMSE = 13.308, R²=0.898 | Testing RMSE=27.259, R²=0.764
# CatBoost: CV Training RMSE = 14.076, R²=0.886 | Testing RMSE=26.177, R²=0.782
# ==> Weighted Ensemble - RMSE: 24.778, MAE: 14.831, R²: 0.805

# %%
# Main script for proposed model learning with tuning
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_predict, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import ExtraTreesRegressor, BaggingRegressor
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import RandomizedSearchCV

# Configuration
horizons = [0, 1, 2, 5]
features = ['Longitude','PFG_surface_pressure','Latitude','Slope','Elevation','Year','EVI']
target = 'ALT_Max'


hyperparms_ET = {0: {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 20},
                 1: {'n_estimators': 700, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 50},
                 2: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 20},
                 5: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.9, 'max_depth': 20}}

hyperparms_Bagging = {0: {'n_estimators': 2500, 'max_samples': 1.0, 'max_features': 1.0, 'bootstrap_features': False},
                 1: {'n_estimators': 2500, 'max_samples': 1.0, 'max_features': 0.8, 'bootstrap_features': False},
                 2: {'n_estimators': 2000, 'max_samples': 1.0, 'max_features': 1.0, 'bootstrap_features': True},
                 5: {'n_estimators': 2500, 'max_samples': 1.0, 'max_features': 0.9, 'bootstrap_features': False}}

hyperparms_cat = {0: {'bagging_temperature': 5, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.1, 'l2_leaf_reg': 7, 'iterations': 1500},
                 1: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 4, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 2500},
                 2: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 2500},
                 5: {'bagging_temperature': 1, 'random_strength': 1, 'depth': 6, 'learning_rate': 0.05, 'l2_leaf_reg': 1, 'iterations': 2500}}

# Load and evaluate
for hrz in horizons:
    # Dynamically define models for the current horizon
    models = [
        ('Extra Trees', ExtraTreesRegressor(random_state=42, **hyperparms_ET[hrz])),
        ('Bagging Regressor', BaggingRegressor(random_state=42, **hyperparms_Bagging[hrz])),
        ('CatBoost', CatBoostRegressor(verbose=0, random_seed=42, **hyperparms_cat[hrz]))
    ]
    print(f'\n*********************** HRZ = {hrz} years')
    train_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    test_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    train_info = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv', usecols=['MainRegion', 'Region', 'Location', 'Latitude', 'Longitude', 'Year'])
    test_info = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv', usecols=['MainRegion', 'Region', 'Location', 'Latitude', 'Longitude', 'Year'])

    train_data = train_data[features + [target]]
    test_data = test_data[features + [target]]

    X_train = train_data.drop(columns=target)
    y_train = train_data[target]
    X_test = test_data.drop(columns=target)
    y_test = test_data[target]

    preds_test = {}
    preds_train_cv = {}
    rmse_scores = {}

    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    # Step 2: CV predictions and RMSE
    for name, model in models:
        y_pred_cv = cross_val_predict(model, X_train, y_train, cv=cv, n_jobs=-1)
        model.fit(X_train, y_train)
        y_pred_test = model.predict(X_test)

        preds_test[name] = y_pred_test
        preds_train_cv[name] = y_pred_cv

        rmse = np.sqrt(mean_squared_error(y_train, y_pred_cv))
        r2 = r2_score(y_train, y_pred_cv)
        rmse_scores[name] = rmse

        print(f"{name}: CV Training RMSE = {rmse:.3f}, R²={r2:.3f} | Testing RMSE={np.sqrt(mean_squared_error(y_test, y_pred_test)):.3f}, R²={r2_score(y_test, y_pred_test):.3f}")

    # Step 3: Compute CV-based weights
    inverse_rmse = {k: 1 / v for k, v in rmse_scores.items()}
    total_inv = sum(inverse_rmse.values())
    weights = {k: v / total_inv for k, v in inverse_rmse.items()}

    # Step 4: Weighted predictions
    weighted_test_pred = sum(preds_test[m] * weights[m] for m in weights)
    weighted_cv_pred = sum(preds_train_cv[m] * weights[m] for m in weights)

    # Step 5: Evaluate weighted ensemble
    rmse = np.sqrt(mean_squared_error(y_test, weighted_test_pred))
    mae = mean_absolute_error(y_test, weighted_test_pred)
    r2 = r2_score(y_test, weighted_test_pred)
    print(f"==> Weighted Ensemble - RMSE: {rmse:.3f}, MAE: {mae:.3f}, R²: {r2:.3f}")

    # Step 6: Build outputs with metadata
    train_info = train_info.reset_index(drop=True)
    test_info = test_info.reset_index(drop=True)
    y_train = y_train.reset_index(drop=True)
    y_test = y_test.reset_index(drop=True)

    df_train_out = train_info.copy()
    df_test_out = test_info.copy()

    df_train_out['y_train'] = y_train
    df_test_out['y_test'] = y_test

    for name in preds_train_cv:
        df_train_out[f'y_trpred_{name}'] = preds_train_cv[name]
        df_test_out[f'y_tepred_{name}'] = preds_test[name]
        df_train_out[f'weight_{name}'] = weights[name]
        df_test_out[f'weight_{name}'] = weights[name]

    df_train_out['y_trpred_ensemble'] = weighted_cv_pred
    df_train_out['weight_ensemble'] = 1.0
    df_test_out['y_tepred_ensemble'] = weighted_test_pred
    df_test_out['weight_ensemble'] = 1.0

    # Save if needed
    df_train_out.to_csv(f'/content/drive/MyDrive/UND/ALT/ALT_hrz{hrz}_TrainPredictions.csv', index=False)
    df_test_out.to_csv(f'/content/drive/MyDrive/UND/ALT/ALT_hrz{hrz}_TestPredictions.csv', index=False)
# Out:
# *********************** HRZ = 0 years
# Extra Trees: CV Training RMSE = 12.595, R²=0.909 | Testing RMSE=24.946, R²=0.802
# Bagging Regressor: CV Training RMSE = 13.045, R²=0.902 | Testing RMSE=26.362, R²=0.779
# CatBoost: CV Training RMSE = 13.268, R²=0.899 | Testing RMSE=25.493, R²=0.793
# ==> Weighted Ensemble - RMSE: 24.241, MAE: 14.627, R²: 0.813
#
# *********************** HRZ = 1 years
# Extra Trees: CV Training RMSE = 13.063, R²=0.902 | Testing RMSE=24.494, R²=0.809
# Bagging Regressor: CV Training RMSE = 14.206, R²=0.884 | Testing RMSE=26.920, R²=0.770
# CatBoost: CV Training RMSE = 13.703, R²=0.892 | Testing RMSE=26.730, R²=0.773
# ==> Weighted Ensemble - RMSE: 24.328, MAE: 14.653, R²: 0.812
#
# *********************** HRZ = 2 years
# Extra Trees: CV Training RMSE = 12.795, R²=0.906 | Testing RMSE=24.488, R²=0.809
# Bagging Regressor: CV Training RMSE = 14.106, R²=0.886 | Testing RMSE=27.192, R²=0.765
# CatBoost: CV Training RMSE = 13.242, R²=0.899 | Testing RMSE=24.779, R²=0.805
# ==> Weighted Ensemble - RMSE: 24.308, MAE: 13.865, R²: 0.812
#
# *********************** HRZ = 5 years
# Extra Trees: CV Training RMSE = 13.106, R²=0.901 | Testing RMSE=24.654, R²=0.807
# Bagging Regressor: CV Training RMSE = 13.321, R²=0.898 | Testing RMSE=27.324, R²=0.763
# CatBoost: CV Training RMSE = 13.995, R²=0.888 | Testing RMSE=26.023, R²=0.785
# ==> Weighted Ensemble - RMSE: 24.574, MAE: 14.757, R²: 0.808

# %% [markdown]
# ## Benchmark against other models

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# Sklearn models
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# Horizons and config
horizons = [0, 1, 2, 5]
target = 'ALT_Max'

features = ['Longitude','PFG_surface_pressure','Latitude','Slope','Elevation','Year','EVI']

# Conventional ML models
sklearn_models = [
    ('Linear Regression', LinearRegression()),
    ('Ridge', Ridge(alpha=1.0)),
    ('Lasso', Lasso(alpha=0.01)),
    ('ElasticNet', ElasticNet(alpha=0.01, l1_ratio=0.5)),
    ('Decision Tree', DecisionTreeRegressor(random_state=42)),
    ('Random Forest', RandomForestRegressor(n_estimators=100, random_state=42)),
    ('KNN', KNeighborsRegressor(n_neighbors=5)),
    ('SVR', SVR(kernel='rbf')),
    ('MLP', MLPRegressor(hidden_layer_sizes=(200, 100, 50, 25), max_iter=500, random_state=42))
]


# Main loop
for hrz in horizons:
    print(f'\n{"="*15} HRZ = {hrz} years {"="*15}')

    # Load data
    train_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    test_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    train_data = train_data[features + [target]]
    test_data = test_data[features + [target]]

    X_train, y_train = train_data.drop(columns=target), train_data[target]
    X_test, y_test = test_data.drop(columns=target), test_data[target]

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    cv = KFold(n_splits=5, shuffle=True, random_state=42)

    for name, model in sklearn_models:
        try:
            y_pred_cv = cross_val_predict(model, X_train_scaled, y_train, cv=cv)
            model.fit(X_train_scaled, y_train)
            y_pred_test = model.predict(X_test_scaled)

            rmse_cv = np.sqrt(mean_squared_error(y_train, y_pred_cv))
            mae_cv = mean_absolute_error(y_train, y_pred_cv)
            r2_cv = r2_score(y_train, y_pred_cv)
            rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
            mae_test = mean_absolute_error(y_test, y_pred_test)
            r2_test = r2_score(y_test, y_pred_test)

            print(f"{name}: RMSE = {rmse_cv:.3f}, MAE = {mae_cv:.3f}, R² = {r2_cv:.3f}, Test RMSE = {rmse_test:.3f}, MAE = {mae_test:.3f}, R² = {r2_test:.3f}")
        except Exception as e:
            print(f"{name}: FAILED - {str(e)}")
# Out:
# =============== HRZ = 0 years ===============
# Linear Regression: RMSE = 38.789, MAE = 29.240, R² = 0.137, Test RMSE = 54.169, MAE = 38.822, R² = 0.068
# Ridge: RMSE = 38.788, MAE = 29.238, R² = 0.137, Test RMSE = 54.170, MAE = 38.821, R² = 0.068
# Lasso: RMSE = 38.788, MAE = 29.237, R² = 0.137, Test RMSE = 54.171, MAE = 38.821, R² = 0.068
# ElasticNet: RMSE = 38.787, MAE = 29.229, R² = 0.137, Test RMSE = 54.177, MAE = 38.816, R² = 0.067
# Decision Tree: RMSE = 15.972, MAE = 9.550, R² = 0.854, Test RMSE = 33.774, MAE = 19.029, R² = 0.638
# Random Forest: RMSE = 13.200, MAE = 8.202, R² = 0.900, Test RMSE = 26.474, MAE = 14.963, R² = 0.777
# KNN: RMSE = 19.637, MAE = 12.517, R² = 0.779, Test RMSE = 33.002, MAE = 20.572, R² = 0.654
# SVR: RMSE = 35.857, MAE = 25.164, R² = 0.263, Test RMSE = 53.003, MAE = 34.557, R² = 0.107
# MLP: RMSE = 19.118, MAE = 12.814, R² = 0.790, Test RMSE = 30.882, MAE = 21.789, R² = 0.697
#
# =============== HRZ = 1 years ===============
# Linear Regression: RMSE = 38.833, MAE = 29.284, R² = 0.135, Test RMSE = 54.242, MAE = 38.898, R² = 0.065
# Ridge: RMSE = 38.833, MAE = 29.282, R² = 0.135, Test RMSE = 54.243, MAE = 38.897, R² = 0.065
# Lasso: RMSE = 38.833, MAE = 29.281, R² = 0.135, Test RMSE = 54.244, MAE = 38.897, R² = 0.065
# ElasticNet: RMSE = 38.831, MAE = 29.273, R² = 0.135, Test RMSE = 54.250, MAE = 38.891, R² = 0.065
# Decision Tree: RMSE = 17.761, MAE = 10.609, R² = 0.819, Test RMSE = 33.842, MAE = 19.261, R² = 0.636
# Random Forest: RMSE = 13.763, MAE = 8.645, R² = 0.891, Test RMSE = 26.084, MAE = 14.939, R² = 0.784
# KNN: RMSE = 20.007, MAE = 12.874, R² = 0.770, Test RMSE = 33.558, MAE = 20.531, R² = 0.642
# SVR: RMSE = 36.092, MAE = 25.380, R² = 0.253, Test RMSE = 53.181, MAE = 34.718, R² = 0.101
# MLP: RMSE = 19.437, MAE = 13.193, R² = 0.783, Test RMSE = 31.399, MAE = 21.698, R² = 0.687
#
# =============== HRZ = 2 years ===============
# Linear Regression: RMSE = 38.823, MAE = 29.228, R² = 0.135, Test RMSE = 54.286, MAE = 38.998, R² = 0.064
# Ridge: RMSE = 38.823, MAE = 29.227, R² = 0.135, Test RMSE = 54.286, MAE = 38.997, R² = 0.064
# Lasso: RMSE = 38.823, MAE = 29.225, R² = 0.135, Test RMSE = 54.287, MAE = 38.997, R² = 0.064
# ElasticNet: RMSE = 38.822, MAE = 29.218, R² = 0.135, Test RMSE = 54.293, MAE = 38.989, R² = 0.063
# Decision Tree: RMSE = 19.550, MAE = 11.090, R² = 0.781, Test RMSE = 29.761, MAE = 16.995, R² = 0.719
# Random Forest: RMSE = 13.730, MAE = 8.560, R² = 0.892, Test RMSE = 26.257, MAE = 14.271, R² = 0.781
# KNN: RMSE = 20.087, MAE = 12.899, R² = 0.768, Test RMSE = 34.377, MAE = 20.035, R² = 0.624
# SVR: RMSE = 36.164, MAE = 25.429, R² = 0.249, Test RMSE = 53.403, MAE = 34.846, R² = 0.094
# MLP: RMSE = 19.158, MAE = 13.127, R² = 0.789, Test RMSE = 30.502, MAE = 21.424, R² = 0.704
#
# =============== HRZ = 5 years ===============
# Linear Regression: RMSE = 38.824, MAE = 29.230, R² = 0.135, Test RMSE = 54.219, MAE = 38.880, R² = 0.066
# Ridge: RMSE = 38.823, MAE = 29.229, R² = 0.135, Test RMSE = 54.220, MAE = 38.880, R² = 0.066
# Lasso: RMSE = 38.824, MAE = 29.227, R² = 0.135, Test RMSE = 54.221, MAE = 38.879, R² = 0.066
# ElasticNet: RMSE = 38.822, MAE = 29.220, R² = 0.135, Test RMSE = 54.226, MAE = 38.872, R² = 0.066
# Decision Tree: RMSE = 17.161, MAE = 10.186, R² = 0.831, Test RMSE = 34.433, MAE = 17.836, R² = 0.623
# Random Forest: RMSE = 13.415, MAE = 8.399, R² = 0.897, Test RMSE = 26.728, MAE = 14.830, R² = 0.773
# KNN: RMSE = 19.934, MAE = 12.710, R² = 0.772, Test RMSE = 33.717, MAE = 19.770, R² = 0.639
# SVR: RMSE = 36.360, MAE = 25.447, R² = 0.241, Test RMSE = 53.371, MAE = 34.795, R² = 0.095
# MLP: RMSE = 19.633, MAE = 13.506, R² = 0.779, Test RMSE = 30.125, MAE = 20.573, R² = 0.712

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras import layers, models, callbacks, Input, Model
from sklearn.model_selection import KFold
import tensorflow as tf
import os
import random

# Set seeds
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# === Model Architectures ===

import tensorflow as tf
from tensorflow.keras import layers, Model, Input

def bottleneck_block(x, filters, downsample=False):
    shortcut = x

    # 1x1 reduce
    x = layers.Dense(filters, activation='relu')(x)
    x = layers.BatchNormalization()(x)

    # 3x3 process (still Dense)
    x = layers.Dense(filters, activation='relu')(x)
    x = layers.BatchNormalization()(x)

    # 1x1 expand
    x = layers.Dense(filters * 4)(x)
    x = layers.BatchNormalization()(x)

    # Projection shortcut if needed
    if downsample or shortcut.shape[-1] != x.shape[-1]:
        shortcut = layers.Dense(filters * 4)(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def build_resnet50_tabular(input_dim):
    inputs = Input(shape=(input_dim,))
    x = layers.Dense(64)(inputs)  # Initial projection
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    # Block layout: 3, 4, 6, 3 (as in ResNet-50)
    for reps, filters in zip([3, 4, 6, 3], [64, 128, 256, 512]):
        for i in range(reps):
            x = bottleneck_block(x, filters, downsample=(i == 0))

    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(1)(x)
    return Model(inputs, x)


def build_vgg16_tabular(input_dim):
    inputs = Input(shape=(input_dim,))
    x = inputs
    for units in [64, 64, 128, 128, 256, 256, 256, 512, 512, 512, 512, 512, 512]:
        x = layers.Dense(units, activation='relu')(x)
        x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation='relu')(x)
    output = layers.Dense(1)(x)
    return Model(inputs, output)


def build_ft_transformer_continuous(input_dim, num_heads=8, num_blocks=4, dim=64,
                                    attn_dropout=0.1, ff_dropout=0.1):
    inputs = tf.keras.Input(shape=(input_dim,))

    # Project continuous input: [B, F] → [B, F, 1] → [B, F, dim]
    x = tf.keras.layers.Reshape((input_dim, 1))(inputs)
    tokens = tf.keras.layers.Dense(dim)(x)

    # Add CLS token
    cls_token = tf.Variable(tf.random.normal([1, 1, dim]), trainable=True, name='cls_token')
    cls_layer = tf.keras.layers.Lambda(lambda t: tf.concat([tf.tile(cls_token, [tf.shape(t)[0], 1, 1]), t], axis=1))
    tokens = cls_layer(tokens)  # [B, F+1, dim]

    # Positional (column) encodings
    pos_embeds = tf.keras.layers.Embedding(input_dim + 1, dim)
    def add_positional_encoding(x):
        seq_len = tf.shape(x)[1]
        pos_indices = tf.range(start=0, limit=seq_len, delta=1)
        pos_encoding = pos_embeds(pos_indices)
        return x + tf.expand_dims(pos_encoding, axis=0)
    tokens = tf.keras.layers.Lambda(add_positional_encoding)(tokens)

    x = tokens
    for _ in range(num_blocks):
        # Multi-head self-attention with dropout
        attn_input = tf.keras.layers.LayerNormalization()(x)
        attn_output = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads,
            key_dim=dim,
            dropout=attn_dropout
        )(attn_input, attn_input)
        attn_output = tf.keras.layers.Dropout(attn_dropout)(attn_output)
        x = tf.keras.layers.Add()([x, attn_output])

        # Feedforward MLP with dropout
        ff_input = tf.keras.layers.LayerNormalization()(x)
        ff = tf.keras.layers.Dense(dim * 2, activation='relu')(ff_input)
        ff = tf.keras.layers.Dropout(ff_dropout)(ff)
        ff = tf.keras.layers.Dense(dim)(ff)
        ff = tf.keras.layers.Dropout(ff_dropout)(ff)
        x = tf.keras.layers.Add()([x, ff])

    # Regress on the CLS token
    x = tf.keras.layers.Lambda(lambda x: x[:, 0])(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    output = tf.keras.layers.Dense(1)(x)
    return tf.keras.Model(inputs, output)



def build_densenet121_tabular(input_dim):
    inputs = Input(shape=(input_dim,))
    x = layers.Dense(64, activation='relu')(inputs)

    for num_layers in [6, 12, 24, 16]:
        for _ in range(num_layers):
            new_feat = layers.Dense(32, activation='relu')(x)
            x = layers.Concatenate()([x, new_feat])
        x = layers.Dense(64, activation='relu')(x)  # transition layer

    x = layers.Dense(128, activation='relu')(x)
    output = layers.Dense(1)(x)
    return Model(inputs, output)

def build_autoint_continuous(input_dim, embedding_dim=32, num_heads=4, num_layers=3, dropout_rate=0.1):
    inputs = tf.keras.Input(shape=(input_dim,))

    # Per-feature embedding: [B, F] → [B, F, E]
    x = tf.keras.layers.Reshape((input_dim, 1))(inputs)
    x = tf.keras.layers.Dense(embedding_dim)(x)

    for _ in range(num_layers):
        attn_input = tf.keras.layers.LayerNormalization()(x)  # Norm before attention
        attn_output = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=dropout_rate
        )(attn_input, attn_input)

        attn_output = tf.keras.layers.Dropout(dropout_rate)(attn_output)
        x = tf.keras.layers.Add()([x, attn_output])  # residual
        # No activation after residual per original AutoInt

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    output = tf.keras.layers.Dense(1)(x)
    return tf.keras.Model(inputs=inputs, outputs=output)

# === Model Registry ===
model_builders = {
    # "ResNet50_Tab": build_resnet50_tabular,
    # "VGG16_Tab": build_vgg16_tabular,
    # "DenseNet121_Tab": build_densenet121_tabular,
    # "FTTransformer": build_ft_transformer_continuous,
    "AutoInt": build_autoint_continuous,
    }#"MLP-Mixer": build_mlp_mixer

# === Loop Over Horizons ===

results = []
horizons = [0, 1, 2, 5]
target = 'ALT_Max'

features = ['Longitude','PFG_surface_pressure','Latitude','Slope','Elevation','Year','EVI']


for hrz in horizons:
    print(f'\n{"="*15} HRZ = {hrz} years {"="*15}')

    # Load data
    train_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    test_data = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TestDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])

    target = 'ALT_Max'

    train_data = train_data[features + [target]]
    test_data = test_data[features + [target]]

    X_train = train_data[features].values
    y_train = train_data[target].values
    X_test = test_data[features].values
    y_test = test_data[target].values

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    input_dim = X_train_scaled.shape[1]

    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for model_name, build_fn in model_builders.items():
        print(f"\nModel: {model_name}")

        fold_rmse, fold_mae, fold_r2 = [], [], []

        for train_idx, val_idx in kf.split(X_train_scaled):
            X_tr, X_val = X_train_scaled[train_idx], X_train_scaled[val_idx]
            y_tr, y_val = y_train[train_idx], y_train[val_idx]

            model = build_fn(X_tr.shape[1])
            model.compile(optimizer='adam', loss='mse', metrics=['mae'])

            early_stop = callbacks.EarlyStopping(patience=100, restore_best_weights=True, verbose=0)
            model.fit(X_train_scaled, y_train, epochs=20000, batch_size=64,
                      validation_split=0.2, verbose=0, callbacks=[early_stop])

            y_pred = model.predict(X_val).flatten()
            fold_rmse.append(np.sqrt(mean_squared_error(y_val, y_pred)))
            fold_mae.append(mean_absolute_error(y_val, y_pred))
            fold_r2.append(r2_score(y_val, y_pred))

        model_full = build_fn(X_train_scaled.shape[1])
        model_full.compile(optimizer='adam', loss='mse', metrics=['mae'])
        model_full.fit(X_train_scaled, y_train, epochs=20000, batch_size=64,
                      validation_split=0.2, verbose=0, callbacks=[early_stop])
        y_pred_test = model_full.predict(X_test_scaled).flatten()
        rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
        mae = mean_absolute_error(y_test, y_pred_test)
        r2 = r2_score(y_test, y_pred_test)
        print(f'{model_name}, RMSE={np.mean(fold_rmse)}, MAE={np.mean(fold_mae)}, R2={np.mean(fold_r2)}, RMSE={rmse}, MAE={mae}, R2={r2}')

        results.append({
            "Horizon": hrz,
            "Model": model_name,
            "trRMSE": np.mean(fold_rmse),
            "trMAE": np.mean(fold_mae),
            "trR2": np.mean(fold_r2),
            "RMSE": rmse,
            "MAE": mae,
            "R2": r2
        })

# === Display Results ===

results_df = pd.DataFrame(results)
print("\nFinal Results:")
print(results_df)

# Optional: Save to CSV
# results_df.to_csv("ALT_DeepModelSweep_Keras.csv", index=False)

# %% [markdown]
# ## Stats on the selected features

# %%
# !pip install xicorpy pandas numpy scipy statsmodels
# Out:
# Requirement already satisfied: xicorpy in /usr/local/lib/python3.11/dist-packages (0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.4)
# Requirement already satisfied: scikit-learn<2.0,>=1.5 in /usr/local/lib/python3.11/dist-packages (from xicorpy) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.5->xicorpy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0,>=1.5->xicorpy) (3.6.0)

# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
import xicorpy

# Parameters
target = 'ALT_Max'
features = ['Longitude', 'PFG_surface_pressure', 'Latitude', 'Slope', 'Elevation', 'Year', 'EVI']
horizons = [0, 1, 2, 5]

# Initialize dictionary to collect all results
results_dict = {feature: {} for feature in features}

for hrz in horizons:
    # Load and prepare data
    df = pd.read_csv(f'/content/drive/MyDrive/UND/ALT/TrainDatawERA5_{hrz}Years_V3.csv').drop(columns=['MainRegion', 'Region', 'Location'])
    df = df[features + [target]].dropna()

    # Standardize for VIF
    X_scaled = StandardScaler().fit_transform(df[features])
    vif_list = [variance_inflation_factor(X_scaled, i) for i in range(len(features))]
    vif_dict = dict(zip(features, vif_list))

    for feature in features:
        x = df[feature].values
        y = df[target].values
        xi_corr, _ = xicorpy.compute_xi_correlation(x, y, get_p_values=True)
        spear_corr, _ = spearmanr(x, y)

        results_dict[feature][f'Xi h={hrz}'] = xi_corr[0][0]
        # results_dict[feature][f'R h={hrz}'] = spear_corr
        results_dict[feature][f'VIF h={hrz}'] = vif_dict[feature]

# Build DataFrame
results_df = pd.DataFrame.from_dict(results_dict, orient='index')

# Reset index to get Feature as a column
results_df = results_df.reset_index().rename(columns={'index': 'Feature'})
results_df
# Out:
#                 Feature    Xi h=0   VIF h=0    Xi h=1   VIF h=1    Xi h=2  \
# 0             Longitude  0.877587  1.293832  0.877668  1.292808  0.877712
# 1  PFG_surface_pressure  0.292654  1.182320  0.277294  1.169722  0.272236
# 2              Latitude  0.863479  1.479798  0.863570  1.471344  0.863611
# 3                 Slope  0.879904  1.344762  0.879987  1.344362  0.880026
# 4             Elevation  0.873629  1.477361  0.873711  1.477603  0.873754
# 5                  Year  0.317010  1.576118  0.317540  1.638584  0.317708
# 6                   EVI  0.247202  1.753994  0.248141  1.791768  0.276092
#
#     VIF h=2    Xi h=5   VIF h=5
# 0  1.294540  0.877712  1.317113
# 1  1.165739  0.292375  1.156887
# 2  1.479566  0.863611  1.491133
# 3  1.343154  0.880026  1.335490
# 4  1.480348  0.873754  1.488870
# 5  1.687120  0.317708  1.850111
# 6  1.839827  0.337036  2.001901
